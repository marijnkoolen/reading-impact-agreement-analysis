# %%
import json

data_file = "data_en/sentences_done.json"

with open(data_file, 'rt') as fh:
    data = json.load(fh)
    
print('total sentences:', len(data))

sents_done = [sent for sent in data if sent['excluded'] is False]
print('sentences with annotations:', len(sents_done))
# Out:
# total sentences: 563
# sentences with annotations: 338

# %% [markdown]
# ## Basic Functions

# %%
from collections import Counter
from collections import defaultdict


def get_annotator_freq(sents):
    annotator_freq = Counter()
    for sent in sents:
        annotator_freq.update([anno['annotator'] for anno in sent['annotations']])
    return annotator_freq
            

def filter_annotators_by_freq(sents, min_freq=-1, max_freq=-1):
    annotator_freq = get_annotator_freq(sents)
    for sent in sents:
        for anno in sent['annotations']:
            freq = annotator_freq[anno['annotator']]
            if freq < min_freq:
                continue
            elif max_freq > 0 and freq > max_freq:
                continue
            else:
                yield anno


def get_scale_rating(anno, scale):
    if anno['unanswerable']:
        return 'UN'
    elif anno['no_impact']:
        return 0
    else:
        return int(anno[scale])

# %% [markdown]
# ## Analysing Unanswerable Sentences

# %%
scales = [
    'emotional_scale', 'style_scale', 'reflection_scale', 'narrative_scale',
    'surprise_scale', 'attention_scale', 'negative_scale', 'humor_scale'    
]


for sent in data:
    if sent['excluded'] is True:
        continue
    print_sent = False
    for anno in sent['annotations']:
        if anno['unanswerable']:
            print_sent = True
    if not print_sent:
        continue
    print('Sentences:', sent['text'].strip())
    for anno in sent['annotations']:
        if anno['unanswerable']:
            print('\t', anno['annotator'], 'unanswerable')
        elif anno['no_impact']:
            print('\t', anno['annotator'], 'no_impact')
        else:
            print('\t', anno['annotator'], [anno[scale] for scale in scales])
# Out:
# Sentences: It's a feel good book, so that lessens as time goes on.
# 	 aeq969 unanswerable
# 	 nuz535 [4, 0, 0, 0, 0, 0, 1, 0]
# 	 sdu514 [3, 1, 0, 3, 0, 3, 2, 0]
# Sentences: then it just spiralled out of control.
# 	 aeq969 unanswerable
# 	 nuz535 [2, 0, 0, 0, 4, 0, 2, 0]
# 	 sdu514 [2, 0, 0, 2, 3, 0, 2, 0]
# Sentences: And when Walter wants to help, he throws himself into it, heart, mind, time and bank account.
# 	 npo717 unanswerable
# 	 ydv934 ['0', '0', '3', '0', '0', '1', '0', '0']
# 	 upx953 no_impact
# Sentences: A detective of paranormal happenings.
# 	 npo717 unanswerable
# 	 ydv934 ['0', '0', '1', '0', '1', '0', '0', '0']
# 	 upx953 no_impact
# Sentences: And then you'll give me the '2 months later' crap next chapter wherein he's instantly recovered from a brain tumor.
# 	 ifw202 ['0', '0', '0', '0', '2', '3', '3', '0']
# 	 yaq494 unanswerable
# 	 nhf461 ['0', '0', '1', '0', '0', '1', '2', '0']
# Sentences: Well it takes others a little longer.
# 	 ifw202 ['2', '3', '3', '2', '2', '2', '3', '2']
# 	 yaq494 ['0', '0', '4', '0', '3', '3', '4', '0']
# 	 nhf461 unanswerable
# Sentences: And then there was Jacob O'Connor.
# 	 ifw202 ['2', '2', '2', '2', '3', '3', '2', '2']
# 	 yaq494 ['0', '0', '2', '0', '4', '3', '0', '0']
# 	 nhf461 unanswerable
# Sentences: I give it three stars only because the ending provided few details, and I very much like Lee Child's details of Reacher's amazing escapes, for instance, the details in 'Nothing to Lose'.
# 	 nhf461 unanswerable
# 	 gry278 ['2', '3', '2', '3', '3', '2', '2', '1']
# 	 nrb271 ['3', '0', '0', '4', '0', '0', '3', '0']
# Sentences: She responds with "Okay daddy.
# 	 yaq494 unanswerable
# 	 nhf461 unanswerable
# 	 gry278 unanswerable
# Sentences: I cannot wait for Natalie's next book in the series - Beg For Me - that's Xander's cousin's Logan's story.
# 	 nhf461 unanswerable
# 	 gry278 ['3', '2', '2', '2', '2', '3', '0', '1']
# 	 nrb271 no_impact
# Sentences: It also explains many more things that happen in our daily life such as why do we make towels from cotton?
# 	 nhf461 unanswerable
# 	 gry278 ['2', '2', '2', '2', '3', '2', '0', '1']
# 	 nrb271 no_impact
# Sentences: also check marriage and birth certificates after reading joelle's diaries
#  no follow up with boyfriend
#  possibility of fingerprints on finger bandage
#  buy a horse?
# 	 nhf461 unanswerable
# 	 gry278 unanswerable
# 	 nrb271 unanswerable
# Sentences: Yes, I already know this and live it.
# 	 nhf461 unanswerable
# 	 gry278 unanswerable
# 	 nrb271 no_impact
# Sentences: It's usually all about plot - the twists,
# 	 nrb271 ['0', '0', '0', '0', '3', '0', '0', '0']
# 	 nqe273 unanswerable
# 	 der817 unanswerable
# Sentences: In short, PLEASE SUPPORT SARAH ANDERSEN!
# 	 nrb271 ['3', '0', '0', '0', '0', '0', '0', '0']
# 	 ezi755 ['4', '0', '0', '0', '0', '0', '0', '0']
# 	 der817 unanswerable
# Sentences: It seems to be Leo's is worst off than Alex is, with conquering them.
# 	 nrb271 no_impact
# 	 nqe273 unanswerable
# 	 der817 no_impact
# Sentences: The big drama of the German dinner petered off into nothing.
# 	 nrb271 no_impact
# 	 nqe273 unanswerable
# 	 der817 no_impact
# Sentences: Does man-cleavage really go up that high or do you think Rogan's sporting a push-up bra?
# 	 nrb271 no_impact
# 	 ezi755 no_impact
# 	 der817 unanswerable
# Sentences: The fight was a little much - she kind of blew everything out of the water, but I understood where she was coming from I guess.
# 	 nrb271 no_impact
# 	 ezi755 ['0', '0', '0', '0', '0', '0', '2', '0']
# 	 der817 unanswerable
# Sentences: I expect variations in pace.
# 	 nrb271 no_impact
# 	 der817 unanswerable
# 	 gjx882 ['0', '0', '1', '0', '1', '0', '0', '0']
# Sentences: The longer version is 486 pages.
# 	 nrb271 unanswerable
# 	 ezi755 no_impact
# 	 der817 no_impact
# Sentences: In between the gore there is an occasional insight from Nick.
# 	 gjx882 unanswerable
# 	 dpn657 ['1', '0', '0', '1', '1', '1', '3', '0']
# 	 guv635 ['1', '2', '0', '2', '1', '2', '1', '0']
# 	 qdg805 ['0', '0', '0', '0', '0', '0', '3', '0']
# Sentences: Trust me when I say that I got it.
# 	 gjx882 ['0', '0', '1', '0', '0', '0', '0', '0']
# 	 dpn657 unanswerable
# 	 guv635 ['1', '2', '0', '1', '0', '3', '1', '1']
# 	 qdg805 ['0', '0', '4', '0', '1', '2', '0', '0']
# Sentences: Two notoriously corrupt Congressmen and a lobbyist with a bad reputation are found dead.
# 	 gjx882 unanswerable
# 	 dpn657 no_impact
# 	 guv635 ['2', '1', '0', '1', '0', '2', '0', '0']
# 	 qdg805 ['0', '0', '0', '0', '0', '0', '0', '0']
# Sentences: Did that just happen?
# 	 dpn657 ['2', '2', '2', '2', '4', '3', '2', '2']
# 	 guv635 ['1', '1', '0', '2', '4', '1', '0', '0']
# 	 qdg805 ['0', '0', '1', '0', '4', '0', '0', '0']
# 	 hhq065 unanswerable
# Sentences: There is a lot of banter between the characters, and that also happened in Buffy.
# 	 dpn657 unanswerable
# 	 guv635 ['2', '2', '0', '2', '0', '2', '0', '2']
# 	 qdg805 ['2', '2', '2', '2', '0', '0', '0', '2']
# Sentences: Oh, yes!
# 	 dpn657 ['3', '3', '0', '3', '2', '3', '0', '3']
# 	 guv635 ['1', '0', '0', '0', '2', '1', '0', '0']
# 	 qdg805 ['2', '0', '2', '4', '2', '0', '0', '0']
# 	 hhq065 unanswerable
# Sentences: Ok, I finally finished this trilogy.
# 	 dpn657 ['0', '0', '2', '0', '0', '3', '3', '0']
# 	 qdg805 ['0', '0', '1', '0', '0', '4', '1', '0']
# 	 hhq065 unanswerable
# Sentences: I acknowledge my own place in a broken system and my duty to help give others the tools to educate themselves and others through reliable sources.
# 	 dpn657 unanswerable
# 	 qdg805 ['0', '0', '4', '0', '0', '0', '0', '0']
# 	 hhq065 unanswerable
# Sentences: Also love the illustrations - white picture backgrounds with color in the forefront.
# 	 cru076 ['1', '4', '0', '0', '0', '0', '0', '0']
# 	 naz523 no_impact
# 	 sxd639 unanswerable
# Sentences: dead idiot, nothing at all wonderfull about that, makes a mockery of all those people who spend a lifetime being able to live and thrive, and survive in extreme conditions.
# 	 cru076 unanswerable
# 	 naz523 ['0', '0', '4', '0', '0', '0', '0', '0']
# 	 sxd639 ['1', '0', '3', '4', '0', '3', '4', '0']
# Sentences: You don't need me to tell you that a book about lesbians written in 1951 is dated as hell.
# 	 cru076 ['0', '0', '0', '0', '0', '0', '2', '0']
# 	 sxd639 unanswerable
# 	 sdz396 ['0', '0', '2', '0', '0', '0', '0', '0']
# Sentences: I really don't like books that try to romanticize the concept of blood relatives falling in love with each other.
# 	 eoh682 ['2', '1', '2', '3', '3', '3', '2', '1']
# 	 jge523 ['0', '0', '3', '0', '2', '3', '4', '0']
# 	 npo717 unanswerable
# 	 ydv934 ['1', '0', '2', '4', '0', '0', '4', '0']
# 	 hht673 ['0', '0', '2', '0', '0', '0', '3', '0']
# Sentences: "I can't stop thinking about you."
# 	 eoh682 ['3', '1', '1', '1', '3', '3', '1', '1']
# 	 jge523 unanswerable
# 	 ijf406 unanswerable
# 	 hht673 no_impact
# Sentences: She goes to Omega Point and Kenji suddenly appears
# 	 eoh682 ['2', '1', '1', '4', '3', '1', '1', '0']
# 	 jge523 unanswerable
# 	 uid010 unanswerable
# 	 hht673 no_impact
# Sentences: :)
# 	 xlr671 ['4', '0', '0', '0', '0', '0', '0', '0']
# 	 pkm714 unanswerable
# 	 pie341 unanswerable
# Sentences: I will move on to read some more of Hugh's!
# 	 gsq702 ['2', '0', '0', '0', '0', '0', '0', '0']
# 	 nas031 ['4', '0', '0', '0', '0', '0', '0', '0']
# 	 vbp813 unanswerable
# Sentences: If you're using these kinds of love interchangeably, you're doing it wrong.
# 	 nas031 ['2', '0', '0', '2', '0', '0', '3', '0']
# 	 vbp813 unanswerable
# 	 mjf920 no_impact
# Sentences: There are choices that the author makes that aren't unlike Hillary Mantel using "he" throughout Wolf Hall.
# 	 vcw157 unanswerable
# 	 hgx670 no_impact
# 	 drc700 ['1', '4', '1', '0', '0', '0', '1', '0']
# Sentences: It's the 1970s but woman's emancipation has been slow to arrive.
# 	 vcw157 unanswerable
# 	 hgx670 no_impact
# 	 pgu653 ['1', '0', '0', '3', '3', '3', '2', '0']
# Sentences: First of all, while there are moments in Go Set a Watchman that pulled me in, I didn't feel connected to Scout - sorry, Jean Louise - or Atticus or any of the characters I knew from To Kill a Mockingbird, though I was sad about Jem's absence.
# 	 dtw334 unanswerable
# 	 cru076 ['1', '0', '1', '1', '0', '1', '4', '0']
# 	 kqt280 ['2', '2', '2', '3', '0', '3', '3', '0']
# Sentences: 3.5/5 stars
#  I am a huge fan of fantasy books and that is why this book has caught my attention- plus the beautiful cover!
# 	 sdu514 ['2', '2', '0', '2', '0', '0', '0', '0']
# 	 cru076 unanswerable
# 	 kqt280 ['1', '0', '0', '0', '0', '0', '0', '0']
# Sentences: The Light Between Oceans offers a strange reading experience.
# 	 mlh640 ['2', '2', '3', '2', '4', '1', '2', '2']
# 	 cru076 unanswerable
# 	 kqt280 ['0', '0', '3', '0', '4', '3', '0', '0']
# Sentences: Sons of Anarchy fans!
# 	 yik909 ['2', '0', '1', '2', '0', '0', '0', '0']
# 	 cru076 no_impact
# 	 kqt280 unanswerable
# Sentences: But the book does excellent as showing that.
# 	 hgx670 unanswerable
# 	 mlh640 unanswerable
# 	 ajx513 ['4', '0', '0', '2', '0', '0', '1', '0']
# Sentences: Through subterfuge, force manipulation and assassination.
# 	 whs510 no_impact
# 	 cru076 no_impact
# 	 kqt280 unanswerable
# Sentences: And Scotland shamed itself with an appalling ballad by Alasdair Gray.
# 	 hgx670 unanswerable
# 	 sdu514 ['0', '0', '0', '0', '0', '0', '4', '0']
# 	 lbp656 ['0', '0', '0', '0', '1', '0', '3', '0']
# Sentences: Probably not, but you never know.
# 	 hax813 unanswerable
# 	 sdu514 ['0', '0', '0', '0', '0', '0', '1', '0']
# 	 lbp656 ['0', '0', '1', '0', '3', '0', '0', '0']
# Sentences: 5 moving stars
# 	 mlh640 ['4', '2', '4', '3', '3', '4', '0', '0']
# 	 sdu514 ['4', '0', '0', '4', '0', '0', '0', '0']
# 	 pde699 unanswerable
# Sentences: It is because it's society's way of saying they are nothing?
# 	 trk345 ['0', '0', '2', '0', '2', '0', '0', '0']
# 	 cru076 unanswerable
# 	 lbp656 ['0', '0', '4', '0', '0', '0', '0', '0']
# Sentences: The sound of rain is perfect, with the wind blowing in the audio
# 	 hgx670 unanswerable
# 	 sdu514 no_impact
# 	 lbp656 no_impact
# Sentences: If that's not a good enough reason to read a book, I don't know what is!
# 	 whs510 ['4', '4', '4', '4', '4', '4', '0', '1']
# 	 cru076 unanswerable
# 	 lbp656 ['4', '0', '0', '0', '0', '0', '0', '0']
# Sentences: The literary equivalent of fast food.
# 	 trk345 ['2', '0', '0', '0', '0', '2', '1', '0']
# 	 cru076 unanswerable
# 	 lbp656 ['0', '0', '1', '0', '0', '3', '0', '0']
# Sentences: I'll be honest, I can see where this book might not be for everybody
# 	 hgx670 unanswerable
# 	 hax813 ['3', '0', '3', '0', '0', '0', '0', '0']
# 	 lbp656 no_impact
# Sentences: no way, especially the last few chapters.
# 	 hgx670 no_impact
# 	 hax813 unanswerable
# 	 lbp656 ['0', '0', '0', '0', '2', '0', '0', '0']
# Sentences: It makes sense why some of them seemed to be their own people and that's because Rowling made them feel that way.
# 	 uiq372 ['3', '1', '0', '2', '0', '0', '0', '0']
# 	 mjd186 unanswerable
# 	 war861 ['2', '0', '0', '4', '0', '0', '0', '0']
# Sentences: To begin, our own perceptions of our involvement can be disturbed by the realities of war.
# 	 uiq372 ['0', '0', '4', '0', '0', '0', '0', '0']
# 	 mjd186 unanswerable
# 	 war861 no_impact
# Sentences: Each animal is illustrated using a heart shape.
# 	 qdg805 no_impact
# 	 vcw157 unanswerable
# 	 war861 no_impact
# Sentences: FrozenRobot of all people should know that there is nothing beautiful or endearing or glamorous about sadness.
# 	 pgp535 ['0', '0', '0', '0', '0', '0', '4', '0']
# 	 eac355 unanswerable
# 	 war861 ['0', '0', '0', '0', '0', '0', '4', '0']
# Sentences: but I'd probably start with a different novel.
# 	 uiq372 ['0', '0', '0', '0', '0', '0', '1', '0']
# 	 ygm904 unanswerable
# 	 war861 ['0', '0', '0', '0', '0', '0', '4', '0']
# Sentences: is a story about memory and a family torn apart by a tragedy they can't give voice to.
# 	 uiq372 no_impact
# 	 byl595 ['0', '0', '0', '0', '0', '0', '0', '0']
# 	 vlh718 unanswerable
# Sentences: I read HP Mallory's jolie Wilkins books and really enjoyed them, so I thought I'd give her Dulcie O'Neil series a try while I'm waiting for the third installment of Jolie Wilkins to come out.
# 	 pgp535 no_impact
# 	 eac355 ['4', '0', '0', '0', '0', '2', '0', '0']
# 	 vlh718 unanswerable
# Sentences: This book takes place seven years later, when the two have grown up a lot and wind up working together and are forced to confront the ghosts of their failed relationship.
# 	 qow112 no_impact
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# Sentences: This is the second book I've read by Whaley
# 	 uiq372 no_impact
# 	 seu474 no_impact
# 	 vlh718 unanswerable
# Sentences: Indians, soldiers and even those who claimed to be friends each become almost too big of a problem to handle.
# 	 uiq372 no_impact
# 	 seu474 no_impact
# 	 vlh718 unanswerable
# Sentences: Not quite as entertining as My BIg Fat Greek wedding
# 	 ovk109 ['0', '0', '0', '0', '0', '0', '3', '0']
# 	 eac355 ['0', '0', '0', '0', '0', '0', '2', '0']
# 	 vlh718 unanswerable
# Sentences: It's to the level of an epic fantasy though it doesn't feel that way.
# 	 ovk109 no_impact
# 	 eac355 ['2', '2', '0', '0', '1', '0', '0', '0']
# 	 vlh718 unanswerable
# Sentences: I really wanted to smack her!
# 	 uiq372 ['0', '0', '0', '0', '0', '0', '1', '0']
# 	 seu474 ['0', '0', '0', '0', '0', '0', '4', '0']
# 	 vlh718 unanswerable
# 	 bct067 ['0', '0', '3', '0', '0', '3', '4', '0']
# Sentences: In the midst of this, Sophia is trying her best to live with the whispering voices in her head and she discovers that Cruors (vampire-like beings) and other elemental creatures exist.
# 	 ovk109 no_impact
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# Sentences: My generational niche is inherently suspicious and resentful of any method of categorization.
# 	 ovk109 no_impact
# 	 eac355 unanswerable
# 	 vlh718 unanswerable
# Sentences: Bernardo was left behind in San Andres, Philippines, when his mother got a job in England
# 	 qow112 no_impact
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# Sentences: Do You Want to Start a Scandal opens on the evening of the Parkhurst ball.
# 	 qow112 no_impact
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# Sentences: It should have been called The Fall of Hurstwood.
# 	 pgp535 unanswerable
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# Sentences: Granted, I read the book for the content...
# 	 uiq372 no_impact
# 	 seu474 no_impact
# 	 vlh718 unanswerable
# Sentences: And honestly, Dave didn't have any.
# 	 qow112 unanswerable
# 	 eac355 no_impact
# 	 vlh718 ['0', '0', '0', '0', '0', '0', '4', '0']
# Sentences: He is a widower with no children.
# 	 ovk109 no_impact
# 	 eac355 no_impact
# 	 vlh718 unanswerable
# 	 bct067 no_impact
# Sentences: Hunter-gatherer societies are fully engaged in obtaining food and nobody is exempt.
# 	 ovk109 no_impact
# 	 war861 ['0', '0', '0', '0', '0', '0', '0', '0']
# 	 vlh718 unanswerable
# 	 bct067 no_impact
# Sentences: His dark hair is a sex mess, as if he just ran his hand through it.
# 	 ovk109 no_impact
# 	 war861 ['0', '0', '0', '0', '0', '0', '0', '0']
# 	 vlh718 unanswerable
# 	 bct067 no_impact
# Sentences: I don't know why anyone has attempted this theme since.
# 	 ovk109 no_impact
# 	 war861 ['0', '0', '0', '0', '0', '0', '2', '0']
# 	 vlh718 unanswerable
# Sentences: but no one fully trusts him.
# 	 ovk109 no_impact
# 	 war861 ['0', '0', '0', '0', '0', '0', '4', '0']
# 	 vlh718 unanswerable
# Sentences: Whew.
# 	 qow112 unanswerable
# 	 war861 ['0', '0', '0', '0', '2', '0', '0', '0']
# 	 vlh718 unanswerable
# 	 bct067 no_impact
# Sentences: And a Holocaust survivor!
# 	 ovk109 no_impact
# 	 eac355 unanswerable
# 	 vlh718 unanswerable
# 	 bct067 no_impact

# %% [markdown]
# Above each sentence with at least one annotation of `unanswerable` is shown, together with the annotations by the annotators.
#
# #### Observations
#
# - For some sentences, all or most annotators agree that the sentence is uninterpretable, therefore, that the questions are unanswerable.
#     - Of these sentences, some are indeed hard to interpret. That is, it could be that the sentence expresses some form of reading impact, but you probably need to see the preceding sentences in the review to figure that out. So you can't say there is no impact, but neither can you say that there is. Some examples:
#         - _also check marriage and birth certificates after reading joelle's diaries \\ no follow up with boyfriend \\ possibility of fingerprints on finger bandage \\ buy a horse?_
#         - _Yes, I already know this and live it._
#         - _I acknowledge my own place in a broken system and my duty to help give others the tools to educate themselves and others through reliable sources._
#         - _:)_
#     - Others seems to be descriptive sentences, i.e. describing some aspect of the story. Here the unanswerable annotation seem to express that there is no impact. Some examples:
#         - _She responds with "Okay daddy._
#         - _She goes to Omega Point and Kenji suddenly appears_
#
# #### Findings
#
# The `unanswerable` annotations seem to be a mixed bag of interpretations, with examples that are genuinely uninterpretable, others where annotators seem to signal _no impact_ instead. However, it is difficult to determine if an annotator intended `no_impact` or actually considered the sentence to be uninterpretable.

# %% [markdown]
# ## Rating Tendencies of Individual Annotators

# %%
annotator_freq = get_annotator_freq(sents_done)

anno_freq = defaultdict(Counter)

for sent in sents_done:
    for anno in sent['annotations']:
        if anno['unanswerable']:
            anno_freq[anno['annotator']].update(['unanswerable'])
        elif anno['no_impact']:
            anno_freq[anno['annotator']].update(['no_impact'])
        else:
            anno_freq[anno['annotator']].update([int(anno[scale]) for scale in scales])
            
print('Total: total number of sentences annotated')
print('ANS: number of sentences answered')
print('UNANS: number of sentences that could not be answered')
print('NO_IM: number of sentences labelled as having no impact')
print()
print(f'Annotator    Total ANS UNANS NO_IM\t {" ".join([f"{score: >3}" for score in range(0,5)])}')
print('------------------------------------------------------------')
for annotator, freq in annotator_freq.most_common():
    scores = [anno_freq[annotator][rating] for rating in range(0,5)]
    score_string = ' '.join([f"{score: >3}" for score in scores])
    unanswerable = anno_freq[annotator]['unanswerable']
    answerable = annotator_freq[annotator] - unanswerable
    answer_string = f"{answerable: >6}{unanswerable: >6}{anno_freq[annotator]['no_impact']: >6}"
    print(f'{annotator: <12}', f"{annotator_freq[annotator]: >2}", answer_string, '\t', score_string)
# Out:
# Total: total number of sentences annotated
# ANS: number of sentences answered
# UNANS: number of sentences that could not be answered
# NO_IM: number of sentences labelled as having no impact
#
# Annotator    Total ANS UNANS NO_IM	   0   1   2   3   4
# ------------------------------------------------------------
# cru076       80     74     6    32 	 256  25  14   4  37
# ovk109       59     59     0    26 	 195  12  16  28  13
# hgx670       50     46     4    19 	 164   2  10  20  20
# lbp656       50     50     0    17 	 189  20  22  22  11
# war861       47     47     0     9 	 242   2   9   2  49
# sdu514       40     40     0     5 	 184   7  28  31  30
# naz523       40     40     0    13 	 161   8  18   9  20
# vlh718       38     17    21     0 	 102   0   0   0  34
# nrb271       30     28     2    16 	  63   4  10  12   7
# uiq372       30     30     0     6 	 121  24  11  21  15
# eac355       30     27     3    10 	 102   9  12   5   8
# nhf461       20     12     8     0 	  54  13  18   6   5
# der817       20     15     5     9 	  30   1   3   7   7
# dpn657       20     17     3     2 	  26  20  34  32   8
# qdg805       20     20     0     2 	  96   8  18   7  15
# wlv622       20     20     0     8 	  68   5   6   5  12
# bct067       18     18     0     6 	  57   5   2  11  21
# vbp813       10      8     2     0 	  24  11  14  11   4
# aeq969       10      8     2     2 	  32   4   1   0  11
# nuz535       10     10     0     0 	  55  10   4   2   9
# ydv934       10     10     0     0 	  41  12   7  16   4
# ifw202       10     10     0     0 	   8   8  32  28   4
# yaq494       10      8     2     0 	  20   0  14   7  23
# gry278       10      7     3     0 	   5  15  23  12   1
# ezi755       10     10     0     4 	  35   1   3   3   6
# gjx882       10      8     2     0 	  49   5   0   6   4
# guv635       10     10     0     0 	  37  17  16   2   8
# hhq065       10      6     4     0 	  31   0  10   1   6
# sxd639       10      8     2     1 	  14   4  14  10  14
# ukp255       10     10     0     0 	  52  12  10   5   1
# sdz396       10     10     0     3 	  41   4   4   1   6
# xlr671       10     10     0     0 	  40  13  12   6   9
# pkm714       10      9     1     1 	   9  14   8  20  13
# eoh682       10     10     0     0 	  13  25  17  18   7
# hht673       10     10     0     4 	  24   8   7   6   3
# pie341       10      9     1     2 	  32   2   4   7  11
# mjd186       10      8     2     0 	  25   3  14   7  15
# nas031       10     10     0     2 	  45   1   3   7   8
# vcw157       10      7     3     0 	  27   0   1  10  18
# drc700       10     10     0     3 	  34   6   1   6   9
# seu474       10     10     0     3 	  40   2   1   2  11
# whs510       10     10     0     2 	   8  13   6  10  27
# yik909       10     10     0     1 	  39  10   9  10   4
# mlh640       10      9     1     1 	  18  10  11   7  18
# xtv059       10     10     0     0 	  46  11  15   6   2
# xuq713       10     10     0     0 	  61   8   3   0   8
# ajx513       10     10     0     2 	  40   7   5   3   9
# pde699       10      9     1     2 	   7  16  20  10   3
# trk345       10     10     0     0 	  47   8  13   6   6
# hax813       10      8     2     2 	  37   2   0   5   4
# rte579       10     10     0     0 	   7   8  30  18  17
# qow112       10      8     2     3 	  28   2   1   1   8
# nqe273        9      6     3     0 	  21   2  11  12   2
# kqt280        9      7     2     0 	  35   6   6   8   1
# pgp535        9      8     1     3 	  34   2   1   1   2
# npo717        8      5     3     0 	  14   4   9  10   3
# jge523        8      6     2     0 	  14   2  19   7   6
# mjf920        5      5     0     1 	   7   1   1   9  14
# upx953        4      4     0     2 	   8   2   1   4   1
# sjw608        4      4     0     0 	  17   3   2   7   3
# oaw038        4      4     0     1 	   6   4   5   7   2
# xeh409        4      4     0     0 	  26   2   1   2   1
# ebf417        3      3     0     0 	   6   5   5   3   5
# pgu653        3      3     0     0 	  10   7   1   5   1
# ntu036        2      2     0     0 	   6   4   2   2   2
# gsq702        2      2     0     1 	   7   0   1   0   0
# dtw334        2      1     1     1 	   0   0   0   0   0
# nve684        2      2     0     2 	   0   0   0   0   0
# ygm904        2      1     1     1 	   0   0   0   0   0
# riq511        1      1     0     1 	   0   0   0   0   0
# jot226        1      1     0     1 	   0   0   0   0   0
# ehp730        1      1     0     1 	   0   0   0   0   0
# ijf406        1      0     1     0 	   0   0   0   0   0
# uid010        1      0     1     0 	   0   0   0   0   0
# kyi500        1      1     0     0 	   1   2   4   1   0
# awi797        1      1     0     0 	   6   0   0   0   2
# xym980        1      1     0     1 	   0   0   0   0   0
# jao767        1      1     0     0 	   7   0   1   0   0
# byl595        1      1     0     0 	   8   0   0   0   0

# %% [markdown]
# #### Observations
#
# - Annotators tend to do complete batches of 10 sentences, most do one batch, some do multiple. Few annotators do only part of a batch.
# - The annotators who do more than 10 sentences, use `no_impact` more often than `unanswerable`. The `no_impact` option translates to a score of 0 for all impact scales.
#     - Some annotators seem to use the `unanswerable` option for both uninterpretable sentences and sentences that express no reading impact. E.g. annotators _vlh718_ and _nhf461_ never use `no_impact` and only use `unanswerable`.
#     - Vice versa, some seem to only use `no_impact`, e.g. _ovk109_ and _lbp656_. It is possible that they feel comfortable interpreting the review author's intention without any further context. Given that `no_impact` is more common than `unanswerable`, it is also possible that annotators who only use `no_impact` only encountered sentences they felt confident about interpreting.
# - There are big differences in rating behaviour when annotators do assign ratings.
#     - Some tend to rate 'all or nothing' with the majority of ratings being 0, 3 or 4, e.g. _war861_, _hgx670_, _vlh718_ and _bct067_.
#     - Others tend to avoid very high ratings, e.g. _nhf461_, _dpn657_ and _vbp813_ rarely use score 4.
#     - Yet others tend to pick central values, e.g. _ifw202_ and _gry278_ rarely score 0 or 4, and 2 more often than 1 and 3.
#
# These observations together suggest that individual annotator differ strongly in how they interpreted the answer options and rating scale. This further suggests that either annotator's responses need to debiased or that annotators need to be instructed and trained before starting the actual annotation task.

# %% [markdown]
# ## Rating Tendencies for Individual Impact Categories

# %%
annotator_freq = get_annotator_freq(sents_done)

impact_freq = defaultdict(Counter)

for sent in sents_done:
    for anno in sent['annotations']:
        if anno['unanswerable']:
            anno_freq[anno['annotator']].update(['unanswerable'])
        elif anno['no_impact']:
            for scale in scales:
                impact_freq[scale].update([0])
        else:
            for scale in scales:
                impact_freq[scale].update([int(anno[scale])])
            
print('Total: total number of sentences annotated')
print('ANS: number of sentences answered')
print('UNANS: number of sentences that could not be answered')
print('NO_IM: number of sentences labelled as having no impact')
print()
print(f'Annotator\t    Total\t {" ".join([f"{score: >3}" for score in range(0,5)])}')
print('------------------------------------------------------------')
for scale in scales:
    scores = [impact_freq[scale][rating] for rating in range(0,5)]
    score_string = ' '.join([f"{score: >3}" for score in scores])
    print(f'{scale: <22}{sum(scores)}\t', score_string)
# Out:
# Total: total number of sentences annotated
# ANS: number of sentences answered
# UNANS: number of sentences that could not be answered
# NO_IM: number of sentences labelled as having no impact
#
# Annotator	    Total	   0   1   2   3   4
# ------------------------------------------------------------
# emotional_scale       955	 439  67 112 119 218
# style_scale           955	 709  59  73  58  56
# reflection_scale      955	 658  95  77  68  57
# narrative_scale       955	 596  40  86  95 138
# surprise_scale        955	 719  56  84  58  38
# attention_scale       955	 637  57  77 100  84
# negative_scale        955	 681  66  79  62  67
# humor_scale           955	 847  43  46   9  10

# %% [markdown]
# #### Observations
#
# - There are substantial differences in the rating distributions of the different impact categories.
#     - The _emotional impact_ category has 516 non-zero ratings.
#     - The _humor_ category has 108 non-zero ratings.
#
# - For some categories, annotators tend to choose high ratings (signalling the category is clearly present), such as _emotional impact_ and _narrative feeling_, while for others they tend to choose low ratings (signalling the category is vaguely present), such as _reflection_ and especially _humor_.
#     - For emotional impact, annotators find impact expressed in more than half of the sentences, and when they find it, it is mostly clear (rating 4 is by far the most frequent, and ratings 3 and 4 together make up 65% of all non-zero ratings.
#     - The _humor_ category is less frequently present in sentences, but also least clearly present.
#
# #### Conclusions
#
# - For the more frequent categories, the number of annotated sentences might be enough to reliably establish inter-annotator agreement and agreement between human raters and algorithmic impact models.
# - For the infrequent categories, it is highly likely that more sentences need to be annotated to reliably establish agreement.
#
#
# Of course, reliably establishing agreement does not mean that the agreement will be high. The actual agreement is analysed below.

# %% [markdown]
# ## Qualtitative check of answers per scale
#
# Below is code to quickly check the ratings per sentence for a given impact scale:

# %%
scale = 'humor_scale'
scale = 'negative_scale'
scale = 'attention_scale'

for sent in data:
    if sent['excluded'] is True:
        continue
    ratings = [get_scale_rating(anno, scale) for anno in sent['annotations']]
    print(ratings, sent['text'])
    print()
# Out:
# [3, 0, 0, 0] Only three children survived, and Taylor discovers that this trio, plus a Cadet and a Townie, developed an epic friendship that was the foundation of the many mysteries in her life and identity, as well as of the war games.
#
# [0, 0, 0] It should be noted that this is more of a collection of morality tales than historical accounts.
#
# ['UN', 0, 3] It's a feel good book, so that lessens as time goes on.
#
#
# [0, 0, 0] It doesn't get much better than that!
#
# [4, 0, 0] I really loved Anna.
#
# [0, 0, 2] I think it was much better than The Lost Symbol and if you enjoyed the Da Vinci Code you'll enjoy this book.
#
# [4, 4, 4] Just as addicting Perfect Chemistry, I once again stayed up later than I should've to finish it.
#
# ['UN', 0, 0] then it just spiralled out of control.
#
#
# [2, 3, 3] Her prose is delightfully witty and charming, but the shifting barrage of letters, plays and journal entries never lets us get too close to the main characters.
#
#
# [2, 3, 2] I struggled a little with the connection between them... and I don't really understand how some of the secondary characters actually fit.
#
#
# ['UN', 1, 0] And when Walter wants to help, he throws himself into it, heart, mind, time and bank account.
#
#
# [2, 3, 3] I know, I don't normally like the romance, but this one has enough to keep me guessing
#
# [3, 0, 4] The book just needed so much more.
#
# [0, 3, 3] To say this read takes you on a voyage is not giving it enough credit.
#
# ['UN', 0, 0] A detective of paranormal happenings.
#
# [0, 0, 4] and I loved it!
#
# [3, 4, 0] The dual narrative provides a deep connection and level of understanding to both characters, Aly and Brandon.
#
# [3, 2, 3] The techniques are all clearly laid out and there are a good variety of projects to choose from.
#
# [4, 3, 2] This was a wonderful thid book for this series and I'm so happy I got to read their story.
#
# [3, 4, 1] I liked this sequel but not quite as much as the first one (A Dog's Purpose).
#
# [3, 'UN', 1] And then you'll give me the '2 months later' crap next chapter wherein he's instantly recovered from a brain tumor.
#
# [4, 4, 2] Lots of twists and turns and good characters.
#
# [2, 3, 'UN'] Well it takes others a little longer.
#
# [3, 3, 'UN'] And then there was Jacob O'Connor.
#
# [4, 2, 2] i was very happy with the way things ended and while it didn't make much of an impact on me, i'm a true sucker for cliches.
#
# ['UN', 2, 0] I give it three stars only because the ending provided few details, and I very much like Lee Child's details of Reacher's amazing escapes, for instance, the details in 'Nothing to Lose'.
#
# [2, 2, 0] I love the idea behind it and how each monster has thier own ability.
#
# [2, 2, 0] I just hope the dialogue changes up a bit and the stories aren't so thin.
#
# [1, 1, 0] Wow where they right I am in love and just found me a new author to read.
#
# ['UN', 'UN', 'UN'] She responds with "Okay daddy.
#
# ['UN', 3, 0] I cannot wait for Natalie's next book in the series - Beg For Me - that's Xander's cousin's Logan's story.
#
# ['UN', 2, 0] It also explains many more things that happen in our daily life such as why do we make towels from cotton?
#
# ['UN', 'UN', 'UN'] also check marriage and birth certificates after reading joelle's diaries
#  no follow up with boyfriend
#  possibility of fingerprints on finger bandage
#  buy a horse?
#
# ['UN', 'UN', 0] Yes, I already know this and live it.
#
# [0, 0, 1] I was just blown away.
#
# [0, 3, 0] At about 500 pages it's a lot to get through, but I do believe this book is strictly for fans of Meyer's or those who love a good spy thriller with a lot of "Hollywood special effects" and a bit of humor and romance.
#
#
# [2, 3, 3] Stevens' writing is gritty, suspenseful, raw, and haunting.
#
# [2, 3, 4] While I was a little disappointed in this installment of the Hard Ink series, I'll continue reading this series; the writing is too strong and the characters to memorable to ever make me stop.
#
# [2, 2, 0] The story is unusual and intriguing and follows the protagonist, Pythias, daughter of Aristotle, who is at the end of his life when the story begins.
#
# [0, 2, 0] Absolutely best romance, life experience that I've read this year :)
#
# [0, 'UN', 'UN'] It's usually all about plot - the twists,
#
# [1, 0, 1] but since it is getting a bit dated, a lot of it feels less interesting today.
#
# [0, 0, 0] We actually bought a copy for our music history teacher who would appreciate the humor in this book (he was Jewish, sarcastic, clever
#
# [0, 0, 0] With this passion comes the resolution to fight for our future and the things we love.
#
# [0, 0, 'UN'] In short, PLEASE SUPPORT SARAH ANDERSEN!
#
# [0, 0, 0] Soon they are talking and confessing their real intentions and Drakon is surprised to find out that the Prince is the famous rebel that is helping his people.
#
# [0, 'UN', 0] It seems to be Leo's is worst off than Alex is, with conquering them.
#
# [0, 'UN', 0] The big drama of the German dinner petered off into nothing.
#
# [0, 0, 'UN'] Does man-cleavage really go up that high or do you think Rogan's sporting a push-up bra?
#
#
# [0, 0, 0] But he's also more determined than ever to make sure nothing disrupts the unity of the pack.
#
# [0, 0, 'UN'] The fight was a little much - she kind of blew everything out of the water, but I understood where she was coming from I guess.
#
# [0, 0, 0] They lack a certain fierceness, for example.
#
# [0, 'UN', 0] I expect variations in pace.
#
# [0, 0, 0] Where did this boy come from?
#
# [0, 0, 0] She is considered a suspect in her husband's scheme simply because he asked her to move some funds days prior to his arrest.
#
# ['UN', 0, 0] The longer version is 486 pages.
#
#
# [4, 3, 3] And when you read this story, really study the pictures.
#
# [0, 3, 0, 0] And oh, the small romance that happens between him and Seraphina.
#
# [0, 1, 2, 0] This narrator did an excellent job.
#
# ['UN', 1, 2, 0] In between the gore there is an occasional insight from Nick.
#
#
# [0, 'UN', 3, 2] Trust me when I say that I got it.
#
# [0, 2, 1, 0] To me, Yrsa is developing into a fine writer. '
#
# ['UN', 0, 2, 0] Two notoriously corrupt Congressmen and a lobbyist with a bad reputation are found dead.
#
# [3, 1, 0, 'UN'] Did that just happen?
#
# ['UN', 2, 0] There is a lot of banter between the characters, and that also happened in Buffy.
#
# [3, 1, 0, 'UN'] Oh, yes!
#
# [4, 0, 4, 3] Skimmed the rest.
#
# [4, 3, 4] Even if you agree with some of Tillich's conclusions, the book is never less than fully engaging.
#
# [2, 0, 2] I can't wait to read this book with my 4th graders.
#
# [3, 4, 'UN'] Ok, I finally finished this trilogy.
#
# [3, 0, 0] I rue the day Briggs delivers Mercy's last adventure.
#
# [3, 4, 2] I loved this short ebook.
#
# ['UN', 0, 'UN'] I acknowledge my own place in a broken system and my duty to help give others the tools to educate themselves and others through reliable sources.
#
# [0, 0, 4] I wish the author would have explained why that was said, but after that one time, it was never mentioned again.
#
# [2, 1, 4] I couldnt predict what was going to happen
#
# [0, 0, 3] These books have bigger-than-life characters that are still believable.
#
# [0, 0, 'UN'] Also love the illustrations - white picture backgrounds with color in the forefront.
#
# ['UN', 0, 3] dead idiot, nothing at all wonderfull about that, makes a mockery of all those people who spend a lifetime being able to live and thrive, and survive in extreme conditions.
#
# [0, 0, 0] Also, just one other thing that bothered me was when the Marshall in charge of Ember's family said Ember could last a few days without her smartphone because he couldn't afford a smart phone in college.
#
# [0, 0, 2] If I could give this book 10 bazillion stars I would.
#
# [4, 4, 4] I didn't want to work, cook, eat, sleep, nothing but read this book.
#
# [0, 0, 0] What a fun idea to include all different types of vehicles- great for young kids who love to play with trucks!
#
# [0, 0, 4] Thankfully, after all this terrible neglect, Robin is alive and in remission.
#
# [0, 0, 2] A whole other, hidden world; magical creatures; a forbidden love...
#
# [0, 0, 0] On a side note, I have a pet peeve about heroes and heroines with names somehow connected to the theme of the story---this is a book about aliens, with the title "Earth & Sky", and the heroine is called Skylar.
#
# [0, 0, 0] The concept is very interesting--who hasn't wanted at one time or another for their favorite character to jump from the page to real life?
#
#
# [0, 2, 3] Often historical fiction can easily jolt me out of the story -
#
# [0, 0, 0] She saw things that most people would miss and miss much of what others could see.
#
# [0, 0, 0] I like the way Ward handles loss and grief in this one.
#
#
# [1, 0, 1] I found the characters intriguing in this story.
#
# [0, 0, 0] The book was incredibly descriptive.
#
# [0, 0, 0] The author makes sure to note throughout the narrative that these people were not perfect, but were people perfectly matched to their time and when opportunity presented itself they acted on it and changes resulted that shifted or propelled the course of globalization.
#
# [0, 0, 0] I was born to love this book.
#
# [0, 0, 0] I liked them all but the gem of the book is the last story titled "His Brother's Keeper" about a simple-minded boxer and his smarter and not necessarily wiser brother/manager.
#
# [0, 0, 0] But a few things stuck out to me as being useful specifically for fiction writing -- such as the section focused specifically on word choice and such.
#
# [0, 0, 0] It has all the elements of a good fairy tale including wizards, castles, evil queens, enchantment, secrets, a prince, and a beautiful girl.
#
# [0, 0, 4] I've never read manga or seen anime before - I got bored when my older sister would watch Sailor Moon and would tune out when my guy friends would talk about Naruto.
#
# [1, 2, 3] This was a quick enjoyable read.
#
#
# [0, 0, 0] Awesome book.
#
# [0, 0, 0] Music was something John shared with David, his late partner, and he refused to enjoy music without him.
#
# [0, 0, 0] Gage is his usually full of life self, but we get a glimpse at Gage's past and see just how "unsunny"
#
# [0, 0, 0] Blame it on her bollywood-spersed chapters or a whole chapter dedicated to chai.
#
#
# [0, 0, 0] My problem is not quite so much with what's there in the book as opposed to what's not there.
#
# [0, 0, 0] I liked it
#
# [0, 0, 0] Hilarious!
#
# [0, 0, 0] It's alive.
#
# [0, 0, 0] Will is a bit hesitant as he will be at risk if Aya is the killer, but if she is innocent, he needs to find the real killer before another murder takes place.
#
#
# [0, 0, 0] Upon reaching a breaking point, she attempted suicide, only to be rescued by her groom who wishes to help her start a new life elsewhere.
#
# [0, 0, 0] But the next day, the cold stranger returns and deposits her back to her old life.
#
# [0, 0, 0] For you are fed wine and grapes in abound and surrounded by ladies night and day.
#
# [0, 0, 0] The Magi Senate needs Dusty to get close to him, to discover his real motives.
#
# [0, 'UN', 0] You don't need me to tell you that a book about lesbians written in 1951 is dated as hell.
#
# [0, 0, 0] "Because you are," she said "You are the one."
#
#
# [0, 2, 0] Faster-than-light travel is physically impossible, but more than a millennium ago humans had discovered the Flow, a network of streams or tunnels through space-time resembling what other science fiction authors call wormholes.
#
# [0, 2, 0] Being a freelancer may be hard, and may involve all kinds of money worries, but at least I'm not one of the worthless scum this book is aimed at.
#
# [0, 4, 4] Very creepy...
#
# [0, 2, 2] I definitely enjoyed it, for the most part.
#
# [0, 2, 3] I think Dru is an amzing character
#
# [0, 1, 3] Plus a proposal at the end?
#
# [0, 0, 0] With all that being said though.
#
# [0, 2, 2, 2] [rating = C-]
#  Without Seamus Heaney's brilliant translating, I think this would have been a boring story.
#
# [1, 4, 1, 0] And yet, for a while, I saw only a tinkering of adjectival madness but, luckily, a faithful thesaurus was at hand to do my bidding and now, at this current time, if only you could see the lustre of my eyes as I reminisce of reading those foregone pages-oh the delights I have experienced!
#
# [0, 3, 3] I would give a 5 star for the sex but a 1 star for the content.
#
# [3, 3, 'UN', 0, 0] I really don't like books that try to romanticize the concept of blood relatives falling in love with each other.
#
# [1, 3, 3, 3] This is a story about family, their love for one another, mistakes made, secrets, regrets.
#
# [3, 3, 3, 0] If there was ever a man who should have groveled, it was him.
#
# [1, 3, 3, 4] Because it was confusing, it turned many readers completely off.
#
# [4, 4, 2, 0] Sorry, but women exist in the world and do shit literally as much as men.
#
# [3, 'UN', 'UN', 0] "I can't stop thinking about you."
#
# [3, 1, 3, 1] I recommend this book to anyone really!
#
# [1, 4, 0] This is my favorite (so far) of the Twilight books.
#
# [0, 2, 0] Anne Hathaway narrated this and I definitely recommend listening to thr audiobook.
#
# [4, 0, 0] O my readers, I actually enjoyed the dialect, and the whole karma/life lessons from the ''Aslan.''
#
# [4, 0, 0] There was the promise of something that was never realized.
#
#
# [3, 0, 0] He spends his day as a tour guide and being and unattractive, ordinary man with desires and dreams for himself.
#
# [2, 4, 0] remarkably so given that the whole story takes place in a single hospital room!
#
# [1, 'UN', 'UN', 0] She goes to Omega Point and Kenji suddenly appears
#
# [0, 'UN', 'UN'] :)
#
# [0, 0, 4] The dystopian premise is believable--shockingly so.
#
# [0, 1, 4] There is just so much intrigue to each of them, and the world building that Sarah did is just amazing.
#
# [4, 0, 0] It didn't capture my imagination, nor made me connect with the characters.
#
# [1, 0, 0] Without meaning to, she's sucked into the world of Hannibal Lecter, who spurs her on to uncover clues and solve the mystery of the serial killer the media calls Buffalo Bill.
#
# [0, 0, 'UN'] I will move on to read some more of Hugh's!
#
# [3, 3, 4] The damage that can be done to a person is just so deep that I felt it as I read Peach's narrative.
#
# [0, 1, 0] You see Jack train, and learn his revenge and fix-it craft while making the friends that become important to him in later years.
#
#
# [0, 'UN', 0] If you're using these kinds of love interchangeably, you're doing it wrong.
#
#
# [0, 4, 3] Highly recommend for people wanting to read something new
#
# [0, 1, 0] This is probably my least favorite out of the three stories.
#
# [3, 4, 4] This story grabbed me from the beginning, Jade was such a snarky little snot and Ryder was just.....
#
# [4, 4, 4] If you are looking for a suspenseful read that might just keep you up all night until you finish it, this might be a great one to consider!
#
#
# [0, 4, 3] It's like a beautiful painting, where you can look and each time see something new and beautiful and tragic all at once.
#
# [2, 0, 0] The young person who is holding - rather absurdly - and one by one - many people hostage, is obviously a little unbalanced.
#
# [0, 0, 0] LOVE the whole aliens-invasion thing.
#
# [3, 0, 3] I sat, book in my hand, thinking, "
#
# [0, 0, 0] It is still shocking to consider that Black men fought and died in WWII, only to come back to the South where they were expected to "humble down.
#
# ['UN', 0, 0] There are choices that the author makes that aren't unlike Hillary Mantel using "he" throughout Wolf Hall.
#
# ['UN', 0, 3] It's the 1970s but woman's emancipation has been slow to arrive.
#
# [0, 0, 3] There didn't seem to be as much interaction with Jim, Brian and Mart as some of the other books have, but I still enjoyed it.
#
# [0, 0, 0] I'd say it's for kids around 11-14.
#
#
# [0, 0, 3] Great domestic thriller.
#
# [0, 0, 0] I will be reading more of this author.
#
# [3, 3, 4] Initially, I was a bit dubious about the whole travelling back in time via a few drops of a mysterious drug/potion, but I soon overcame that and got wrapped up in the story.
#
# [2, 4, 3] The third book of the trilogy is just as compelling as the other two.
#
# [0, 2, 0] The first one was so much better.
#
# [4, 0, 3] He underscores the wonderful yet also the contradictions among the Nordic cultures.
#
# ['UN', 1, 3] First of all, while there are moments in Go Set a Watchman that pulled me in, I didn't feel connected to Scout - sorry, Jean Louise - or Atticus or any of the characters I knew from To Kill a Mockingbird, though I was sad about Jem's absence.
#
# [0, 0, 1] The quest to find Ashmole 782 is going up a gear, and enemies are getting closer.
#
# [0, 'UN', 0] 3.5/5 stars
#  I am a huge fan of fantasy books and that is why this book has caught my attention- plus the beautiful cover!
#
# [0, 0, 1] Too fairytale-ish when it wasn't a fairytale.
#
# [4, 0, 0] I will admit that I got this book solely because JK Rowling wrote it.
#
# [0, 0, 1] but when I compare it to some of my recent reads, it just doesn't cut the mustard in that respect either.
#
# [1, 'UN', 3] The Light Between Oceans offers a strange reading experience.
#
# [0, 0, 0] it's neighboring city of Rheamyre, depend on caravans from across the desert for supplies.
#
# [0, 0, 0] This edition with text and pictures by Jim LaMarche is beautiful.
#
# [4, 4, 4] For example, a lot of the names were ridiculously difficult to pronounce, and if I can't say a name aloud I tend to get distracted from the story, which is probably a flaw of mine as reader.
#
# [0, 0, 0] It is not a story about whiny teenagers in love, wonderful relations are formed, the characters develop beautifully, they learn to accept themselves and others.
#
# [0, 0, 2] Soon we find out the new P.A. is gunning for Rusty, and charges him with murder in this spectacular case.
#
# [0, 0, 1] It is a ritual that all members of the royal families undergo in order to further the friendship between the two races.
#
# [0, 0, 'UN'] Sons of Anarchy fans!
#
# [4, 4, 4] An excellent World War II era book that was difficult to put down.
#
# [0, 0, 0] That was a good read.
#
# [0, 0, 0] "FLUFF you."
#
# [0, 0, 0] The female charcter plotted as Neve has many unanswered questions which seems very genuine for every person who revolves around a world of reality or maybe dreams that contrasts a different perspective and actually turns out to be true at times.
#
# [0, 2, 1] The situation is so unbalanced she opts to leave the rotation and be given a failing grade than to continue living with the insanity of the facility.
#
# [0, 0, 1] How she deals with her drastically altering life and her emotions and her family and her friends through it all.
#
# [0, 0, 1] the cotton sheets caught between your calves, that soft, luscious body molded by a satin sheath with spaghetti straps.
#
# [0, 0, 0] Then there's the relationship between the two characters.
#
# [0, 4, 0] Great story!
#
# ['UN', 'UN', 0] But the book does excellent as showing that.
#
#
# [0, 0, 0] This book is soooooooo good!
#
# [0, 0, 'UN'] Through subterfuge, force manipulation and assassination.
#
#
# [0, 0, 0] they finally get to Arthur, set a trap for Geirolf (using Reece and Erin as bait - who have bonded, both for expediency and love)...
#
# [0, 2, 0] I see from the comments left at Goodreads that many of us obtained the book through school scholastic programs and it left quite the impression on us all.
#
# [0, 0, 1] I will use this in class as a recommended reading for my "women in politics" lecture.
#
# [4, 2, 4] This is a really interesting memoir about the author's time as a midwife, from the start of her training and through her career as a nurse and as a community midwife.
#
# [0, 0, 0] This book will capture your heart and make you fall in love with primary and secondary characters.
#
# [0, 3, 0] He was the special ingredient that made this book a pleasure to read.
#
#
# [0, 3, 0] Mrs Wilkinson and Etta were a lovely central pairing and their story made me smile on many occasions.
#
# [0, 0, 2] : I agree with you across the board.
#
# [0, 0, 0] The Serpent feeds on fear so he send all his minions out to destroy the world, so people will freak out, which will make him stronger.
#
#
# [0, 0, 4] I loved Blaire's personality she was sassy, funny, extremely witty, I laughed out loud frequently, much to my embarrassment.
#
# [2, 0, 3] it ranks right up there with The Duff: Designated Ugly Fat Friend (still being my favorite of her books.)
#
# [0, 0, 1] It is the story of two people drawn to the same location by the power of their dreams and how they find one another.
#
# ['UN', 0, 0] And Scotland shamed itself with an appalling ballad by Alasdair Gray.
#
# ['UN', 0, 0] Probably not, but you never know.
#
# [0, 4, 1] For that reason, it took longer to read than a best-selling thriller.
#
# [3, 0, 2] The writing wasn't great
#
# [4, 0, 'UN'] 5 moving stars
#
#
# [0, 0, 0] Vieve offers that one of the teachers is needed in London.
#
# [0, 0, 0] but I'll say no more here.
#
#
# [0, 0, 2] There's always more than what is mentioned, but the absolute fun of this book is reading it to find out what else happens.
#
# [2, 1, 0] The courtroom scene near the end is tense as Shylock demands payment.
#
# [2, 0, 3] i hope that means that he gets to go home to his parents...
#
#
# [0, 'UN', 0] It is because it's society's way of saying they are nothing?
#
# [0, 0, 0] I loved the world that Hickey has created.
#
# [2, 0, 0] On the contrary - Rhine was even encouraging it, since she cared more about Gabriel and her escape plan.
#
# [2, 0, 1] I've got to say, it starts out slowly.
#
# [0, 0, 0] The premise is great.
#
# [2, 0, 0] Brian amazed me, I loved what he did with the dog tags and putting a positive spin on things and using them as a countdown.
#
# [3, 0, 0] Kvothe's father sang of the mystical people, the Chandrien, noted by their blue fire, among other things.
#
# [2, 1, 1] Oh, heaven help me, but this man makes my heart skip a beat and sends my pulse racing.
#
# [4, 0, 0] Jaret's life is broken sleeping around makes him forget.
#
# [0, 0, 0] Why are there no chilling references to what Auschwitz really was beyond Bruno's blunted imagination?
#
# [0, 0, 0] But still it was a fun book and should have an important place in the mythos.
#
# [1, 0, 0] I look forward to sharing this with my daughter when she's older.
#
# [0, 0, 0] Mimi is a funny woman, and I loved her inner monologue.
#
# [0, 0, 0] Brilliant!
#
# ['UN', 0, 0] The sound of rain is perfect, with the wind blowing in the audio
#
# [4, 0, 0] Another virgin heroine who goes on about wearing petticoats in the 1990s!
#
# [0, 0, 0] An opening chapter written in the present tense, with a "heavy unwashed odour" which hits you in the room of a suburban police station which is "not even ugly.
#
# [4, 'UN', 0] If that's not a good enough reason to read a book, I don't know what is!
#
#
# [3, 4, 0] I love the Chicagoland Vampire books, they're so easy to get into!
#
# [4, 0, 0] The beginning was good, but all those suspense and fear of national security boiled down to a damn video.
#
# [1, 0, 0] This collection of essays about multicultural detective fiction focuses primarily of American detective fiction.
#
# [2, 'UN', 3] The literary equivalent of fast food.
#
# [2, 0, 0] She is willing to do what it takes to get things done.
#
#
# [0, 0, 0] I also liked the moral message at the end of the book about what life will be like for the future generations if we do not change.
#
# [0, 3, 0] Skye's emotions and actions are just everywhere and Lukas has to be there no matter what.
#
# [0, 1, 0] Furry United Coalition is a paranormal policing division, set to protect humans from the knowledge of, and attacks from, the hidden paranormal world.
#
# [0, 4, 0] My soul is beautifully crushed.
#
# [0, 4, 0] Just wish it was longer!
#
# [0, 0, 0] I seldom give rave reviews or much beyond three stars
#
# [0, 0, 0] Debra-you rocked it once again!!
#
# [0, 0, 0] is a disappointment in this book.
#
# [3, 4, 3] I didn't skim at all.
#
# [0, 0, 0] I didn't knew what to expect.
#
# [0, 0, 0] , that of humanity hitting the rock bottom of depravity and our rotting nature manifesting itself into walking corpses that eat living people - at least that's how I understood it.
#
# [0, 0, 0] I like books about girlfriends that stick together through think and thin.
#
# ['UN', 0, 0] I'll be honest, I can see where this book might not be for everybody
#
# [0, 'UN', 0] no way, especially the last few chapters.
#
# [0, 0, 0] I picture it as the Doctor's sonic screwdriver, and suspect that I'm correct in my assumption.
#
#
# [0, 0, 0] and I didn't like that woven into a book on "writing for your life".
#
# [0, 0, 0] I listened to this book because I have kind of an interest in cryptography and its historical impact.
#
# [0, 0, 0] I read a book called Thirteen Treasures by Michelle Harrison.
#
# [4, 4, 0] Cliffhangers at the end of each chapter, a steady but intense build of suspense and the unsettling sense that something wasn't right
#
# [3, 3, 0] This series is great but this volume is mainly side stories, so although some are enjoyable, it's not quite as gripping as the main storyline.
#
# [3, 0, 0] Why do authors do that!?
#
# [0, 4, 0] This is 21st century required literature.
#
# [0, 0, 0] That sounds an awful lot like another way of creating God in our image.
#
#
# [0, 0, 0] Anthem felt the freedom she never though she needed when she was with Gavin.
#
# [0, 0, 0] It seemed well written
#
# [0, 4, 0] Whales on Stilts is a wonderful kid's book.
#
# [0, 0, 0] I love romance but don't enjoy reading all the sex scenes.
#
# [0, 0, 0] She finds him disgusting.
#
# [0, 0, 0] Still Here is a beautiful and emotional second chance love story of love and healing, heartbreak, betrayal, forgiveness, trust, passion, sizzling-hot chemistry, and finding yourself.
#
# [3, 3, 0] I really felt the book was dragging and slow at times, so to see how quickly the end came it was a let down.
#
#
# [0, 0, 0] cause those at least had SOME human relations and feelings in them.
#
# [0, 0, 0] Lu is truly a wordsmith, an artist, a truly rewarding author to read.
#
# [0, 0, 0] In all the years they were apart, Penny never gave up on Michael.
#
# [0, 0, 0] I loved how he cared about Lydia and the way he treats her!
#
# [0, 0, 0] so it really took me back to high school days.
#
# [0, 0, 0] In 1972, Nicole Stephane, who held the film rights to Proust's work, asked Joseph Losey if he would like to work on a film version.
#
# [2, 4, 0] The decision she is forced to make tears her apart and will have a major impact on her family and friends.
#
# [1, 4, 0] This book was different than anything I've read before.
#
#
# [4, 4, 4] Although in my honest opinion not as good as Tremayne's previous novel The Ice Twins, it is one that I read in one sitting, turning the pages like an addict and I was kept hungry and excited for more.
#
#
# [0, 0, 0] I thought the end of the book was a little far-fetched, but it didn't disappoint me.
#
# [0, 'UN', 0] It makes sense why some of them seemed to be their own people and that's because Rowling made them feel that way.
#
# [0, 'UN', 0] To begin, our own perceptions of our involvement can be disturbed by the realities of war.
#
# [0, 'UN', 0] Each animal is illustrated using a heart shape.
#
# [0, 0, 0] The language is infrequent, but it goes beyond my usual comfort level of "damn" or "hell".
#
# [1, 3, 0] I see this is a series - I am curious who Daisy ends up with.
#
# [0, 'UN', 0] FrozenRobot of all people should know that there is nothing beautiful or endearing or glamorous about sadness.
#
# [0, 0, 0] On each page there is a map of the county, some facts and pros and cons.
#
# [0, 0, 0] I thought the story was an example of how a child may internalize verbal abuse and it becomes a self-fulfilling prophecy.
#
# [0, 0, 0] He's trapped in this situation and all he can do is try to make the best of it.
#
# [3, 0, 0] It was ludicrous to me that any father would raise his daughters like that, or that anyone would even consider getting married at 18 "just because," or that it would be a problem to go to college out of state.
#
# [2, 0, 2] Definitely want to read more now!
#
# [0, 0, 0] I loved AJ, for all his belligerent ways he had a heart of gold and as much as he was unwilling to admit, he had feelings for our Jillian.
#
#
# [0, 0, 0] She is electrocuted on the ice, which seemed impossible but wasn't.
#
# [1, 0, 0] If you liked the first one a lot, this one is worth your time, but otherwise...
#
# [3, 0, 0] Happy Reading
#
# [3, 0, 0] perfect
#
# [0, 'UN', 0] but I'd probably start with a different novel.
#
# [1, 0, 0] After a really good childhood story, we are presented with a REALLY bad story about being a woman and insanity.
#
# [2, 0, 0] This book however, was different.
#
# [3, 0, 0] I can't say how real it was, but it sounded like it is, and I commend Courtney Summers for this.
#
#
# [3, 0, 0] It's an awesome and unique concept.
#
# [2, 0, 0] Oh, and read Life After Life first.
#
# [2, 0, 0] Books!
#
# [2, 0, 0] We get to visit with all of the beloved characters we met in earlier books, plus we meet some new, fun and exciting characters who add dimension and flavor to the series.
#
# [2, 0, 0, 0] I thought the topic of undocumented workers was interesting, and rather current in the political arena.
#
# [2, 0, 0, 4] They hero, Gaston and heroine, Remington had great chemistry and some wonderfully written sex scene, not graphic or erotica, very nicely written.
#
#
# [1, 0, 0, 0] I expected to see the rest of Charles' mistresses waltz through the pages, but the others only get a few words or a quick reference at most.
#
#
# [1, 0, 0, 0] It was quick-witted and full of fun romance.
#
# [0, 0, 'UN'] is a story about memory and a family torn apart by a tragedy they can't give voice to.
#
# [3, 0, 0] This book was good!
#
# [0, 2, 'UN'] I read HP Mallory's jolie Wilkins books and really enjoyed them, so I thought I'd give her Dulcie O'Neil series a try while I'm waiting for the third installment of Jolie Wilkins to come out.
#
# [0, 0, 0] This book is a perfect feel good read.
#
# [1, 2, 0] I loved it and am eagerly awaiting number 21.
#
# [3, 0, 0, 4] The plot....is another well crafted piece of entertainment.
#
# [0, 0, 0] The writing and structure gives the work a sense of an illumed experience.
#
# [0, 0, 'UN'] This book takes place seven years later, when the two have grown up a lot and wind up working together and are forced to confront the ghosts of their failed relationship.
#
#
# [0, 0, 'UN'] This is the second book I've read by Whaley
#
# [0, 0, 'UN'] Indians, soldiers and even those who claimed to be friends each become almost too big of a problem to handle.
#
#
# [0, 0, 'UN'] Not quite as entertining as My BIg Fat Greek wedding
#
# [0, 0, 'UN'] It's to the level of an epic fantasy though it doesn't feel that way.
#
# [0, 0, 'UN', 3] I really wanted to smack her!
#
# [0, 0, 0] And in the end:
#  Wut?!
#
#
# [0, 0, 'UN'] In the midst of this, Sophia is trying her best to live with the whispering voices in her head and she discovers that Cruors (vampire-like beings) and other elemental creatures exist.
#
#
# [0, 'UN', 'UN'] My generational niche is inherently suspicious and resentful of any method of categorization.
#
# [0, 0, 'UN'] Bernardo was left behind in San Andres, Philippines, when his mother got a job in England
#
# [0, 0, 'UN'] Do You Want to Start a Scandal opens on the evening of the Parkhurst ball.
#
# ['UN', 0, 'UN'] It should have been called The Fall of Hurstwood.
#
# [0, 0, 'UN'] Granted, I read the book for the content...
#
# [0, 0, 0, 0] You get the perfect Alpha Male in Nick, he is totally swoon-worthy with a dirty mouth and over-protective tendencies but he also has this really hot sweet side that comes out with Max and then eventually Tess.
#
#
# [3, 0, 0, 0] It was informative, insightful, provocative.
#
# ['UN', 0, 0] And honestly, Dave didn't have any.
#
# [0, 0, 'UN', 0] He is a widower with no children.
#
# [1, 0, 0, 0] I want to make a point about the cover and the title because they almost kept me from reading Girl in Pieces, and I would hate for other readers to miss out on this book for the same reason.
#
# [0, 0, 'UN', 0] Hunter-gatherer societies are fully engaged in obtaining food and nobody is exempt.
#
# [0, 0, 'UN', 0] His dark hair is a sex mess, as if he just ran his hand through it.
#
# [0, 0, 0, 0] The book is well written, it was the characterizations I had trouble with.
#
# [0, 0, 'UN'] I don't know why anyone has attempted this theme since.
#
# [0, 0, 'UN'] but no one fully trusts him.
#
# ['UN', 0, 'UN', 0] Whew.
#
# [0, 'UN', 'UN', 0] And a Holocaust survivor!
#
# [3, 0, 4, 0] These books are awful, but have their own compelling pull.
#
# [0, 0, 0, 0] Read it

# %% [markdown]
# ## Agreement and number of annotations
#
# For many annotation tasks, there is a learning curve and people make increasingly consistent judgements as they make more judgements. This could mean that annotators who make only a handful of annotations, contribute less consistent annotations, therefore contribute more to disagreement than annotators who contribute many annotations.
#
# One way to investigate this is to filter annotations by removing those contributed by annotators who make fewer than 10 or 20 annotations. A consequence of leaving out annotations is that for some sentences, there will be fewer than three judgements. One solution for that is to only focus on sentences that have at least three annotations by annotators with many judgements.
#
# ### Inter-Annotator Agreement Measure
#
# Above we saw that some impact categories rarely occur, which creates a big class imbalance. That is, the annotators indicate that the vast majority of sentences express no _humor impact_. Therefore, it is inevitable that they agree on a large number of sentences where no _humor impact_ is expressed. The inter-rater agreement measure $r_{wg}$ will therefore reflect high agreement, while it is possible that annotator sitll largely disagree about which sentences _do_ express _humor impact_. A measure that better handles these types of class or category imbalances is **Fleiss' Kappa** (a version of Cohen's Kappa for cases with more than 2 annotators).

# %%
from statsmodels.stats.inter_rater import fleiss_kappa
import numpy as np

ratings = [[7,0], [7,0]]
fleiss_kappa(ratings, method='unif')
# Out:
# 1.0

# %%
def get_scale_ratings(sents, scale, binarise: bool = False, binarise_min_rating: int = 2):
    num_cats = 5 if not binarise else 2
    all_ratings = []
    for sent_index, sent in enumerate(sents):
        ratings = []
        for anno in sent['annotations']:
            rating = get_scale_rating(anno, scale)
            if not isinstance(rating, int):
                continue
            if binarise:
                rating = 0 if rating < binarise_min_rating else 1
            ratings.append(rating)
        if len(ratings) < 3:
            continue
        elif len(ratings) > 3:
            ratings = ratings[:3]
        sent_ratings = np.zeros(num_cats)
        for rating in ratings:
            sent_ratings[rating] += 1
        all_ratings.append(sent_ratings)
    return all_ratings


def filter_ratings_by_annotator_freq(sents, min_freq=-1, max_freq=-1):
    annotator_freq = get_annotator_freq(sents)
    if max_freq < min_freq:
        max_freq = 100000000
    filtered_sents = []
    for sent in sents:
        annos = [anno for anno in sent['annotations'] if min_freq <= annotator_freq[anno['annotator']] <= max_freq]
        if len(annos) >= 3:
            filtered_sents.append({'annotations': annos})
    return filtered_sents


def analyse_binarisation(sents, scale):
    print('Scale:', scale)
    ratings = get_scale_ratings(sents, scale, binarise=False)
    print('\tNum sents with 3 ratings:', len(ratings))
    print("\tFleiss' Kappa non-binarised:", fleiss_kappa(ratings))
    ratings = get_scale_ratings(sents, scale, binarise=True, binarise_min_rating=1)
    print("\tFleiss' Kappa binarsed >=1:", fleiss_kappa(ratings))
    ratings = get_scale_ratings(sents, scale, binarise=True, binarise_min_rating=2)
    print("\tFleiss' Kappa binarsed >=2:", fleiss_kappa(ratings))
    ratings = get_scale_ratings(sents, scale, binarise=True, binarise_min_rating=3)
    print("\tFleiss' Kappa binarsed >=3:", fleiss_kappa(ratings))


def analyse_annotator_frequency(sents, scale, binarise: bool = False, binarise_min_rating: int = 1):
    print('Scale:', scale)
    ratings_all = get_scale_ratings(sents, scale, binarise=binarise, binarise_min_rating=binarise_min_rating)
    print('\tNum sents with 3 ratings, all annotators:', len(ratings_all))
    min_freq=10
    filtered_sents = filter_ratings_by_annotator_freq(sents, min_freq=min_freq)
    ratings_10 = get_scale_ratings(filtered_sents, scale, binarise=binarise, binarise_min_rating=binarise_min_rating)
    print(f'\tNum sents with 3 ratings, annotators >{min_freq}:', len(ratings_10))
    min_freq=11
    filtered_sents = filter_ratings_by_annotator_freq(sents, min_freq=min_freq)
    ratings_11 = get_scale_ratings(filtered_sents, scale, binarise=binarise, binarise_min_rating=binarise_min_rating)
    print(f'\tNum sents with 3 ratings, annotators >{min_freq}:', len(ratings_11))
    print("\tFleiss' Kappa all annotators:", fleiss_kappa(ratings_all))
    print(f"\tFleiss' Kappa annotators >10:", fleiss_kappa(ratings_10))
    print(f"\tFleiss' Kappa annotators >11:", fleiss_kappa(ratings_11))

scale = 'humor_scale'
analyse_binarisation(sents_done, scale)

scale = 'attention_scale'
analyse_binarisation(sents_done, scale)
# Out:
# Scale: humor_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.12442149981009688
# 	Fleiss' Kappa binarsed >=1: 0.1902289806903242
# 	Fleiss' Kappa binarsed >=2: 0.2496043668723198
# 	Fleiss' Kappa binarsed >=3: 0.40693196405648024
# Scale: attention_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.19020005798782258
# 	Fleiss' Kappa binarsed >=1: 0.272935277031841
# 	Fleiss' Kappa binarsed >=2: 0.2847126742375327
# 	Fleiss' Kappa binarsed >=3: 0.28299115984735035

# %% [markdown]
# ### Impact of Number of Annotated Sentences
#
# For many annotation tasks, there are learning effects, in that annotators develop their understanding of the task and how to interpret the various categories they need to annotate. It is possible that as annotators annotate more sentences, they become more consistent in their annotations, and converge to more similar interpretations of the annotation categories.
#
#
# Below we look at the agreement among annotators in different subsets of the annotators. We compare the agreement among three groups:
#
# - **All**: All annotators: This includes annotators who stopped after one or a handful of sentences.
# - **10**: Annotators who annotated at least a full batch of 10 sentences: these annotators perserved through at least a full batch, so have had more chance of coming across multiple sentences that express a certain impact category, but in different ways or with a different degree.
# - **>10**: Annotators who annotated at more than a full batch of 10 sentences, were willing to do more, so may have perceived this as a task they understood and enjoyed enough to continue with a new batch. The frequency distribution at the top of this notebook shows that annotators who did more than 10 sentences all did at least 18 sentences.
#
# ### Impact of Binarisation
#
# We also look at the affect on agreement of using the full rating scale versus different binarisations, where the scale is reduced to either zero or one. For instance:
#
# - **>=1**: a binarisation of $r_{b} = 1 \leftarrow r >=1$ where any rating above zero is mapped to $1$, as it is a signal that a category is present, or
# - **>=3**: a binarisation of $r_{b} = 1 \leftarrow r >=3$ where any rating of 3 or 4 is mapped to $1$. This binarisation means only when the annotator thought the impact category is clearly present, is it counted as presence of that category.

# %%
scales = [
    'emotional_scale', 'style_scale', 'reflection_scale', 'narrative_scale',
    'surprise_scale', 'attention_scale', 'negative_scale', 'humor_scale'    
]

for scale in scales:
    analyse_binarisation(sents_done, scale)
# Out:
# Scale: emotional_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.3356974305191401
# 	Fleiss' Kappa binarsed >=1: 0.5688705942886545
# 	Fleiss' Kappa binarsed >=2: 0.6089611499220988
# 	Fleiss' Kappa binarsed >=3: 0.5684552073440963
# Scale: style_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.18391330573871112
# 	Fleiss' Kappa binarsed >=1: 0.2868237899398928
# 	Fleiss' Kappa binarsed >=2: 0.29841070479687004
# 	Fleiss' Kappa binarsed >=3: 0.36458755325836417
# Scale: reflection_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.0910033334781772
# 	Fleiss' Kappa binarsed >=1: 0.18803418803418803
# 	Fleiss' Kappa binarsed >=2: 0.12918660287081338
# 	Fleiss' Kappa binarsed >=3: 0.0752808376049735
# Scale: narrative_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.23324424935812277
# 	Fleiss' Kappa binarsed >=1: 0.39665634674922606
# 	Fleiss' Kappa binarsed >=2: 0.33957115009746597
# 	Fleiss' Kappa binarsed >=3: 0.361477403661503
# Scale: surprise_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.1862083586148412
# 	Fleiss' Kappa binarsed >=1: 0.2516596059721135
# 	Fleiss' Kappa binarsed >=2: 0.25536547433903584
# 	Fleiss' Kappa binarsed >=3: 0.36057692307692296
# Scale: attention_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.19020005798782258
# 	Fleiss' Kappa binarsed >=1: 0.272935277031841
# 	Fleiss' Kappa binarsed >=2: 0.2847126742375327
# 	Fleiss' Kappa binarsed >=3: 0.28299115984735035
# Scale: negative_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.28218481370513365
# 	Fleiss' Kappa binarsed >=1: 0.5233973240255961
# 	Fleiss' Kappa binarsed >=2: 0.5162147793726743
# 	Fleiss' Kappa binarsed >=3: 0.456047551532338
# Scale: humor_scale
# 	Num sents with 3 ratings: 266
# 	Fleiss' Kappa non-binarised: 0.12442149981009688
# 	Fleiss' Kappa binarsed >=1: 0.1902289806903242
# 	Fleiss' Kappa binarsed >=2: 0.2496043668723198
# 	Fleiss' Kappa binarsed >=3: 0.40693196405648024

# %%
scales = [
    'emotional_scale', 'style_scale', 'reflection_scale', 'narrative_scale',
    'surprise_scale', 'attention_scale', 'negative_scale', 'humor_scale'    
]

min_freq=10
filtered_sents = filter_ratings_by_annotator_freq(sents_done, min_freq=min_freq)
print(f'sentences with annotations by raters with at least {min_freq} sentences:', len(filtered_sents))

for scale in scales:
    analyse_binarisation(filtered_sents, scale)
# Out:
# sentences with annotations by raters with at least 10 sentences: 267
# Scale: emotional_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.31898119466815883
# 	Fleiss' Kappa binarsed >=1: 0.5629123233611703
# 	Fleiss' Kappa binarsed >=2: 0.6019286403085822
# 	Fleiss' Kappa binarsed >=3: 0.5718149931633076
# Scale: style_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.1879508727941095
# 	Fleiss' Kappa binarsed >=1: 0.28111068036441195
# 	Fleiss' Kappa binarsed >=2: 0.30118167109672955
# 	Fleiss' Kappa binarsed >=3: 0.349579831932773
# Scale: reflection_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.0783242540547233
# 	Fleiss' Kappa binarsed >=1: 0.15318288269107957
# 	Fleiss' Kappa binarsed >=2: 0.10031971914866906
# 	Fleiss' Kappa binarsed >=3: 0.09016279715104945
# Scale: narrative_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.2316517428845537
# 	Fleiss' Kappa binarsed >=1: 0.3786991062562062
# 	Fleiss' Kappa binarsed >=2: 0.3618731578621927
# 	Fleiss' Kappa binarsed >=3: 0.3860752056404229
# Scale: surprise_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.16397118068124786
# 	Fleiss' Kappa binarsed >=1: 0.22548814868956807
# 	Fleiss' Kappa binarsed >=2: 0.2116666666666663
# 	Fleiss' Kappa binarsed >=3: 0.33153330060546643
# Scale: attention_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.17069989989622278
# 	Fleiss' Kappa binarsed >=1: 0.26398669796557117
# 	Fleiss' Kappa binarsed >=2: 0.2365839373306971
# 	Fleiss' Kappa binarsed >=3: 0.24283600810471728
# Scale: negative_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.2883672154069668
# 	Fleiss' Kappa binarsed >=1: 0.5287306501547985
# 	Fleiss' Kappa binarsed >=2: 0.505813953488372
# 	Fleiss' Kappa binarsed >=3: 0.4662745448852703
# Scale: humor_scale
# 	Num sents with 3 ratings: 215
# 	Fleiss' Kappa non-binarised: 0.11014502053388142
# 	Fleiss' Kappa binarsed >=1: 0.17777429887730922
# 	Fleiss' Kappa binarsed >=2: 0.21973955738988152
# 	Fleiss' Kappa binarsed >=3: 0.45396825396825446

# %%
scales = [
    'emotional_scale', 'style_scale', 'reflection_scale', 'narrative_scale',
    'surprise_scale', 'attention_scale', 'negative_scale', 'humor_scale'    
]

min_freq=11
filtered_sents = filter_ratings_by_annotator_freq(sents_done, min_freq=min_freq)
print(f'sentences with annotations by raters with at least {min_freq} sentences:', len(filtered_sents))

for scale in scales:
    analyse_binarisation(filtered_sents, scale)
# Out:
# sentences with annotations by raters with at least 11 sentences: 61
# Scale: emotional_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.376592036466014
# 	Fleiss' Kappa binarsed >=1: 0.6532716927453769
# 	Fleiss' Kappa binarsed >=2: 0.6771879483500718
# 	Fleiss' Kappa binarsed >=3: 0.6368038740920097
# Scale: style_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.26547743966421816
# 	Fleiss' Kappa binarsed >=1: 0.3355481727574753
# 	Fleiss' Kappa binarsed >=2: 0.431818181818182
# 	Fleiss' Kappa binarsed >=3: 0.44852941176470656
# Scale: reflection_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.16219839142091194
# 	Fleiss' Kappa binarsed >=1: 0.37033582089552225
# 	Fleiss' Kappa binarsed >=2: 0.3262212240314427
# 	Fleiss' Kappa binarsed >=3: 0.20774647887324027
# Scale: narrative_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.40662373505059773
# 	Fleiss' Kappa binarsed >=1: 0.6237458193979932
# 	Fleiss' Kappa binarsed >=2: 0.6462264150943395
# 	Fleiss' Kappa binarsed >=3: 0.6188496188496188
# Scale: surprise_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.3848857644991207
# 	Fleiss' Kappa binarsed >=1: 0.45652173913043503
# 	Fleiss' Kappa binarsed >=2: 0.5271867612293134
# 	Fleiss' Kappa binarsed >=3: 0.5504495504495502
# Scale: attention_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.1432540907687564
# 	Fleiss' Kappa binarsed >=1: 0.3055555555555556
# 	Fleiss' Kappa binarsed >=2: 0.2424242424242435
# 	Fleiss' Kappa binarsed >=3: 0.3659420289855077
# Scale: negative_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.5036572622779519
# 	Fleiss' Kappa binarsed >=1: 0.8338870431893687
# 	Fleiss' Kappa binarsed >=2: 0.6682883679787699
# 	Fleiss' Kappa binarsed >=3: 0.41137998691955546
# Scale: humor_scale
# 	Num sents with 3 ratings: 50
# 	Fleiss' Kappa non-binarised: 0.30394431554524465
# 	Fleiss' Kappa binarsed >=1: 0.29078014184397205
# 	Fleiss' Kappa binarsed >=2: 0.5862068965517238
# 	Fleiss' Kappa binarsed >=3: 0.7431506849315047

# %%
scales = [
    'emotional_scale', 'style_scale', 'reflection_scale', 'narrative_scale',
    'surprise_scale', 'attention_scale', 'negative_scale', 'humor_scale'    
]

for scale in scales:
    analyse_annotator_frequency(sents_done, scale, binarise=True, binarise_min_rating=1)
# Out:
# Scale: emotional_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.5688705942886545
# 	Fleiss' Kappa annotators >10: 0.5629123233611703
# 	Fleiss' Kappa annotators >11: 0.6532716927453769
# Scale: style_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.2868237899398928
# 	Fleiss' Kappa annotators >10: 0.28111068036441195
# 	Fleiss' Kappa annotators >11: 0.3355481727574753
# Scale: reflection_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.18803418803418803
# 	Fleiss' Kappa annotators >10: 0.15318288269107957
# 	Fleiss' Kappa annotators >11: 0.37033582089552225
# Scale: narrative_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.39665634674922606
# 	Fleiss' Kappa annotators >10: 0.3786991062562062
# 	Fleiss' Kappa annotators >11: 0.6237458193979932
# Scale: surprise_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.2516596059721135
# 	Fleiss' Kappa annotators >10: 0.22548814868956807
# 	Fleiss' Kappa annotators >11: 0.45652173913043503
# Scale: attention_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.272935277031841
# 	Fleiss' Kappa annotators >10: 0.26398669796557117
# 	Fleiss' Kappa annotators >11: 0.3055555555555556
# Scale: negative_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.5233973240255961
# 	Fleiss' Kappa annotators >10: 0.5287306501547985
# 	Fleiss' Kappa annotators >11: 0.8338870431893687
# Scale: humor_scale
# 	Num sents with 3 ratings, all annotators: 266
# 	Num sents with 3 ratings, annotators >10: 215
# 	Num sents with 3 ratings, annotators >11: 50
# 	Fleiss' Kappa all annotators: 0.1902289806903242
# 	Fleiss' Kappa annotators >10: 0.17777429887730922
# 	Fleiss' Kappa annotators >11: 0.29078014184397205

# %% [markdown]
# #### Observations
#
# The binarisation has, almost by definition, a positive impact on agreement.

# %% [markdown]
# ## Disagreeing annotators
#
# Some annotators disagree more often with other annotators than other annotators. Check how often and by how much annotators disagree.
#
# Purpose: Can we identify people who either interpreted impact categories very differently from others, or give random answers or purposefully wrong answers?

# %%
from collections import defaultdict, Counter
from itertools import combinations

from scripts_en.human_rater_analysis import get_rater_scores
from scripts_en.config import config


agreed = defaultdict(Counter)

for sent in data:
    if sent['excluded'] is True:
        continue
    ratings = []
    for anno in sent['annotations']:
        for anno1, anno2 in combinations(sent['annotations'], 2):
            rating1 = get_scale_rating(anno1, scale)
            rating2 = get_scale_rating(anno2, scale)
            if (rating1 == "UN" and rating2 != "UN") or (rating1 != "UN" and rating2 == "UN"):
                diff = -1
            elif rating1 == "UN" and rating2 == "UN":
                diff = 0
            else:
                diff = abs(rating1 - rating2)
            agreed[anno1['annotator']].update([diff])
            agreed[anno2['annotator']].update([diff])
                
        scores = get_rater_scores(sent, scale, config)
    print([get_scale_rating(anno, scale) for anno in sent['annotations']], [anno['annotator'] for anno in sent['annotations']])
# Out:
# [3, 0, 0, 0] ['vbp813', 'aeq969', 'sdu514', 'nuz535']
# [0, 0, 0] ['aeq969', 'nuz535', 'sdu514']
# ['UN', 0, 3] ['aeq969', 'nuz535', 'sdu514']
# [0, 0, 0] ['aeq969', 'sdu514', 'nuz535']
# [4, 0, 0] ['aeq969', 'sdu514', 'nuz535']
# [0, 0, 2] ['aeq969', 'nuz535', 'sdu514']
# [4, 4, 4] ['aeq969', 'nuz535', 'sdu514']
# ['UN', 0, 0] ['aeq969', 'nuz535', 'sdu514']
# [2, 3, 3] ['npo717', 'ydv934', 'upx953']
# [2, 3, 2] ['ydv934', 'ebf417', 'ifw202']
# ['UN', 1, 0] ['npo717', 'ydv934', 'upx953']
# [2, 3, 3] ['npo717', 'ydv934', 'upx953']
# [3, 0, 4] ['npo717', 'ydv934', 'ebf417']
# [0, 3, 3] ['ydv934', 'npo717', 'ifw202']
# ['UN', 0, 0] ['npo717', 'ydv934', 'upx953']
# [0, 0, 4] ['npo717', 'ydv934', 'ebf417']
# [3, 4, 0] ['ifw202', 'yaq494', 'nhf461']
# [3, 2, 3] ['ifw202', 'yaq494', 'nhf461']
# [4, 3, 2] ['ifw202', 'yaq494', 'nhf461']
# [3, 4, 1] ['ifw202', 'yaq494', 'nhf461']
# [3, 'UN', 1] ['ifw202', 'yaq494', 'nhf461']
# [4, 4, 2] ['ifw202', 'yaq494', 'nhf461']
# [2, 3, 'UN'] ['ifw202', 'yaq494', 'nhf461']
# [3, 3, 'UN'] ['ifw202', 'yaq494', 'nhf461']
# [4, 2, 2] ['yaq494', 'nhf461', 'gry278']
# ['UN', 2, 0] ['nhf461', 'gry278', 'nrb271']
# [2, 2, 0] ['nhf461', 'gry278', 'nrb271']
# [2, 2, 0] ['nhf461', 'gry278', 'nrb271']
# [1, 1, 0] ['nhf461', 'gry278', 'nrb271']
# ['UN', 'UN', 'UN'] ['yaq494', 'nhf461', 'gry278']
# ['UN', 3, 0] ['nhf461', 'gry278', 'nrb271']
# ['UN', 2, 0] ['nhf461', 'gry278', 'nrb271']
# ['UN', 'UN', 'UN'] ['nhf461', 'gry278', 'nrb271']
# ['UN', 'UN', 0] ['nhf461', 'gry278', 'nrb271']
# [0, 0, 1] ['nhf461', 'nrb271', 'nqe273']
# [0, 3, 0] ['nrb271', 'nqe273', 'ezi755']
# [2, 3, 3] ['nhf461', 'nrb271', 'ezi755']
# [2, 3, 4] ['nrb271', 'nqe273', 'der817']
# [2, 2, 0] ['nrb271', 'nqe273', 'der817']
# [0, 2, 0] ['nrb271', 'nqe273', 'der817']
# [0, 'UN', 'UN'] ['nrb271', 'nqe273', 'der817']
# [1, 0, 1] ['nrb271', 'ezi755', 'der817']
# [0, 0, 0] ['nrb271', 'ezi755', 'der817']
# [0, 0, 0] ['nrb271', 'nqe273', 'der817']
# [0, 0, 'UN'] ['nrb271', 'ezi755', 'der817']
# [0, 0, 0] ['nrb271', 'ezi755', 'der817']
# [0, 'UN', 0] ['nrb271', 'nqe273', 'der817']
# [0, 'UN', 0] ['nrb271', 'nqe273', 'der817']
# [0, 0, 'UN'] ['nrb271', 'ezi755', 'der817']
# [0, 0, 0] ['nrb271', 'ezi755', 'der817']
# [0, 0, 'UN'] ['nrb271', 'ezi755', 'der817']
# [0, 0, 0] ['nrb271', 'der817', 'gjx882']
# [0, 'UN', 0] ['nrb271', 'der817', 'gjx882']
# [0, 0, 0] ['nrb271', 'der817', 'gjx882']
# [0, 0, 0] ['nrb271', 'der817', 'riq511']
# ['UN', 0, 0] ['nrb271', 'ezi755', 'der817']
# [4, 3, 3] ['der817', 'gjx882', 'dpn657']
# [0, 3, 0, 0] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# [0, 1, 2, 0] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# ['UN', 1, 2, 0] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# [0, 'UN', 3, 2] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# [0, 2, 1, 0] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# ['UN', 0, 2, 0] ['gjx882', 'dpn657', 'guv635', 'qdg805']
# [3, 1, 0, 'UN'] ['dpn657', 'guv635', 'qdg805', 'hhq065']
# ['UN', 2, 0] ['dpn657', 'guv635', 'qdg805']
# [3, 1, 0, 'UN'] ['dpn657', 'guv635', 'qdg805', 'hhq065']
# [4, 0, 4, 3] ['dpn657', 'guv635', 'qdg805', 'hhq065']
# [4, 3, 4] ['dpn657', 'qdg805', 'hhq065']
# [2, 0, 2] ['dpn657', 'qdg805', 'hhq065']
# [3, 4, 'UN'] ['dpn657', 'qdg805', 'hhq065']
# [3, 0, 0] ['dpn657', 'hhq065', 'qdg805']
# [3, 4, 2] ['dpn657', 'qdg805', 'hhq065']
# ['UN', 0, 'UN'] ['dpn657', 'qdg805', 'hhq065']
# [0, 0, 4] ['cru076', 'naz523', 'sxd639']
# [2, 1, 4] ['cru076', 'naz523', 'sxd639']
# [0, 0, 3] ['cru076', 'naz523', 'sxd639']
# [0, 0, 'UN'] ['cru076', 'naz523', 'sxd639']
# ['UN', 0, 3] ['cru076', 'naz523', 'sxd639']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 0, 2] ['cru076', 'naz523', 'sxd639']
# [4, 4, 4] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 0, 4] ['cru076', 'naz523', 'sxd639']
# [0, 0, 2] ['cru076', 'naz523', 'sxd639']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 2, 3] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [1, 0, 1] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'ukp255']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 4] ['cru076', 'naz523', 'wlv622']
# [1, 2, 3] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 0, 0] ['cru076', 'naz523', 'wlv622']
# [0, 'UN', 0] ['cru076', 'sxd639', 'sdz396']
# [0, 0, 0] ['cru076', 'naz523', 'sdz396']
# [0, 2, 0] ['sdz396', 'xlr671', 'jot226']
# [0, 2, 0] ['sdz396', 'xlr671', 'ehp730']
# [0, 4, 4] ['sdz396', 'xlr671', 'ntu036']
# [0, 2, 2] ['sdz396', 'xlr671', 'ntu036']
# [0, 2, 3] ['sdz396', 'xlr671', 'pkm714']
# [0, 1, 3] ['sdz396', 'xlr671', 'pkm714']
# [0, 0, 0] ['cru076', 'sxd639', 'sdz396']
# [0, 2, 2, 2] ['nuz535', 'sdu514', 'eoh682', 'hht673']
# [1, 4, 1, 0] ['nuz535', 'sdu514', 'eoh682', 'hht673']
# [0, 3, 3] ['sdz396', 'xlr671', 'pkm714']
# [3, 3, 'UN', 0, 0] ['eoh682', 'jge523', 'npo717', 'ydv934', 'hht673']
# [1, 3, 3, 3] ['eoh682', 'jge523', 'sjw608', 'hht673']
# [3, 3, 3, 0] ['eoh682', 'jge523', 'sjw608', 'hht673']
# [1, 3, 3, 4] ['eoh682', 'jge523', 'ydv934', 'hht673']
# [4, 4, 2, 0] ['eoh682', 'jge523', 'sjw608', 'hht673']
# [3, 'UN', 'UN', 0] ['eoh682', 'jge523', 'ijf406', 'hht673']
# [3, 1, 3, 1] ['eoh682', 'jge523', 'sjw608', 'hht673']
# [1, 4, 0] ['xlr671', 'pkm714', 'pie341']
# [0, 2, 0] ['pkm714', 'pie341', 'uiq372']
# [4, 0, 0] ['pkm714', 'pie341', 'uiq372']
# [4, 0, 0] ['pkm714', 'pie341', 'uiq372']
# [3, 0, 0] ['pkm714', 'pie341', 'uiq372']
# [2, 4, 0] ['xlr671', 'pkm714', 'pie341']
# [1, 'UN', 'UN', 0] ['eoh682', 'jge523', 'uid010', 'hht673']
# [0, 'UN', 'UN'] ['xlr671', 'pkm714', 'pie341']
# [0, 0, 4] ['pie341', 'uiq372', 'mjd186']
# [0, 1, 4] ['pie341', 'uiq372', 'mjd186']
# [4, 0, 0] ['pie341', 'uiq372', 'mjd186']
# [1, 0, 0] ['kyi500', 'gsq702', 'nas031']
# [0, 0, 'UN'] ['gsq702', 'nas031', 'vbp813']
# [3, 3, 4] ['nas031', 'vbp813', 'mjf920']
# [0, 1, 0] ['nas031', 'vbp813', 'aeq969']
# [0, 'UN', 0] ['nas031', 'vbp813', 'mjf920']
# [0, 4, 3] ['nas031', 'mjf920', 'vbp813']
# [0, 1, 0] ['nas031', 'vbp813', 'awi797']
# [3, 4, 4] ['nas031', 'vbp813', 'aeq969']
# [4, 4, 4] ['nas031', 'mjf920', 'vbp813']
# [0, 4, 3] ['nas031', 'mjf920', 'vbp813']
# [2, 0, 0] ['dpn657', 'hhq065', 'qdg805']
# [0, 0, 0] ['vcw157', 'hgx670', 'drc700']
# [3, 0, 3] ['vcw157', 'hgx670', 'drc700']
# [0, 0, 0] ['vcw157', 'hgx670', 'drc700']
# ['UN', 0, 0] ['vcw157', 'hgx670', 'drc700']
# ['UN', 0, 3] ['vcw157', 'hgx670', 'pgu653']
# [0, 0, 3] ['ovk109', 'hgx670', 'oaw038']
# [0, 0, 0] ['ovk109', 'hgx670', 'oaw038']
# [0, 0, 3] ['ovk109', 'hgx670', 'oaw038']
# [0, 0, 0] ['ovk109', 'hgx670', 'oaw038']
# [3, 3, 4] ['uiq372', 'mjd186', 'seu474']
# [2, 4, 3] ['uiq372', 'mjd186', 'seu474']
# [0, 2, 0] ['uiq372', 'mjd186', 'seu474']
# [4, 0, 3] ['whs510', 'cru076', 'xeh409']
# ['UN', 1, 3] ['dtw334', 'cru076', 'kqt280']
# [0, 0, 1] ['whs510', 'cru076', 'xeh409']
# [0, 'UN', 0] ['sdu514', 'cru076', 'kqt280']
# [0, 0, 1] ['yik909', 'cru076', 'kqt280']
# [4, 0, 0] ['whs510', 'cru076', 'xeh409']
# [0, 0, 1] ['sdu514', 'cru076', 'kqt280']
# [1, 'UN', 3] ['mlh640', 'cru076', 'kqt280']
# [0, 0, 0] ['xym980', 'cru076', 'kqt280']
# [0, 0, 0] ['xtv059', 'cru076', 'xeh409']
# [4, 4, 4] ['sdu514', 'cru076', 'xuq713']
# [0, 0, 0] ['cru076', 'naz523', 'xuq713']
# [0, 0, 2] ['sdu514', 'cru076', 'kqt280']
# [0, 0, 1] ['nve684', 'cru076', 'xuq713']
# [0, 0, 'UN'] ['yik909', 'cru076', 'kqt280']
# [4, 4, 4] ['sdu514', 'cru076', 'xuq713']
# [0, 0, 0] ['sdu514', 'cru076', 'xuq713']
# [0, 0, 0] ['sdu514', 'cru076', 'xuq713']
# [0, 0, 0] ['ovk109', 'dtw334', 'ajx513']
# [0, 2, 1] ['ovk109', 'yik909', 'xuq713']
# [0, 0, 1] ['ovk109', 'yik909', 'xuq713']
# [0, 0, 1] ['ovk109', 'yik909', 'xuq713']
# [0, 0, 0] ['ovk109', 'yik909', 'ajx513']
# [0, 4, 0] ['hgx670', 'mlh640', 'ajx513']
# ['UN', 'UN', 0] ['hgx670', 'mlh640', 'ajx513']
# [0, 0, 0] ['ovk109', 'yik909', 'xuq713']
# [0, 0, 'UN'] ['whs510', 'cru076', 'kqt280']
# [0, 0, 0] ['ovk109', 'yik909', 'ajx513']
# [0, 2, 0] ['ovk109', 'sdu514', 'ajx513']
# [0, 0, 1] ['ovk109', 'sdu514', 'pde699']
# [4, 2, 4] ['mlh640', 'sdu514', 'pde699']
# [0, 0, 0] ['ovk109', 'sdu514', 'ajx513']
# [0, 3, 0] ['ovk109', 'sdu514', 'ajx513']
# [0, 3, 0] ['ovk109', 'sdu514', 'ajx513']
# [0, 0, 2] ['ovk109', 'sdu514', 'pde699']
# [0, 0, 0] ['ovk109', 'nve684', 'ajx513']
# [0, 0, 4] ['trk345', 'sdu514', 'pde699']
# [2, 0, 3] ['mlh640', 'sdu514', 'pde699']
# [0, 0, 1] ['mlh640', 'sdu514', 'pde699']
# ['UN', 0, 0] ['hgx670', 'sdu514', 'lbp656']
# ['UN', 0, 0] ['hax813', 'sdu514', 'lbp656']
# [0, 4, 1] ['hgx670', 'sdu514', 'lbp656']
# [3, 0, 2] ['mlh640', 'sdu514', 'pde699']
# [4, 0, 'UN'] ['mlh640', 'sdu514', 'pde699']
# [0, 0, 0] ['ovk109', 'sdu514', 'pde699']
# [0, 0, 0] ['ovk109', 'sdu514', 'pde699']
# [0, 0, 2] ['hgx670', 'sdu514', 'lbp656']
# [2, 1, 0] ['xtv059', 'cru076', 'lbp656']
# [2, 0, 3] ['xtv059', 'cru076', 'lbp656']
# [0, 'UN', 0] ['trk345', 'cru076', 'lbp656']
# [0, 0, 0] ['hgx670', 'sdu514', 'lbp656']
# [2, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [2, 0, 1] ['hgx670', 'sdu514', 'lbp656']
# [0, 0, 0] ['hgx670', 'sdu514', 'lbp656']
# [2, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [3, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [2, 1, 1] ['trk345', 'cru076', 'lbp656']
# [4, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [0, 0, 0] ['trk345', 'cru076', 'lbp656']
# [0, 0, 0] ['trk345', 'cru076', 'lbp656']
# [1, 0, 0] ['trk345', 'cru076', 'lbp656']
# [0, 0, 0] ['trk345', 'cru076', 'lbp656']
# [0, 0, 0] ['hgx670', 'sdu514', 'lbp656']
# ['UN', 0, 0] ['hgx670', 'sdu514', 'lbp656']
# [4, 0, 0] ['whs510', 'cru076', 'lbp656']
# [0, 0, 0] ['yik909', 'cru076', 'lbp656']
# [4, 'UN', 0] ['whs510', 'cru076', 'lbp656']
# [3, 4, 0] ['yik909', 'cru076', 'lbp656']
# [4, 0, 0] ['vcw157', 'hgx670', 'lbp656']
# [1, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [2, 'UN', 3] ['trk345', 'cru076', 'lbp656']
# [2, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [0, 0, 0] ['ovk109', 'hgx670', 'lbp656']
# [0, 3, 0] ['hgx670', 'pgu653', 'lbp656']
# [0, 1, 0] ['hgx670', 'pgu653', 'lbp656']
# [0, 4, 0] ['hgx670', 'mlh640', 'lbp656']
# [0, 4, 0] ['hgx670', 'mlh640', 'lbp656']
# [0, 0, 0] ['ovk109', 'hgx670', 'lbp656']
# [0, 0, 0] ['ovk109', 'hgx670', 'lbp656']
# [0, 0, 0] ['xtv059', 'cru076', 'lbp656']
# [3, 4, 3] ['ovk109', 'hgx670', 'lbp656']
# [0, 0, 0] ['ovk109', 'hgx670', 'lbp656']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# ['UN', 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 'UN', 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['ovk109', 'hgx670', 'lbp656']
# [4, 4, 0] ['ovk109', 'whs510', 'war861']
# [3, 3, 0] ['ovk109', 'whs510', 'war861']
# [3, 0, 0] ['dpn657', 'qdg805', 'war861']
# [0, 4, 0] ['ovk109', 'whs510', 'war861']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['dpn657', 'qdg805', 'war861']
# [0, 0, 0] ['hgx670', 'trk345', 'lbp656']
# [0, 4, 0] ['ovk109', 'whs510', 'war861']
# [0, 0, 0] ['hgx670', 'trk345', 'war861']
# [0, 0, 0] ['hgx670', 'hax813', 'lbp656']
# [0, 0, 0] ['vcw157', 'hgx670', 'war861']
# [3, 3, 0] ['hgx670', 'drc700', 'war861']
# [0, 0, 0] ['vcw157', 'hgx670', 'war861']
# [0, 0, 0] ['hgx670', 'drc700', 'war861']
# [0, 0, 0] ['hgx670', 'drc700', 'war861']
# [0, 0, 0] ['hgx670', 'drc700', 'war861']
# [0, 0, 0] ['hgx670', 'drc700', 'war861']
# [0, 0, 0] ['hgx670', 'drc700', 'war861']
# [2, 4, 0] ['uiq372', 'mjd186', 'war861']
# [1, 4, 0] ['uiq372', 'mjd186', 'war861']
# [4, 4, 4] ['pgp535', 'war861', 'eac355']
# [0, 0, 0] ['vcw157', 'hgx670', 'war861']
# [0, 'UN', 0] ['uiq372', 'mjd186', 'war861']
# [0, 'UN', 0] ['uiq372', 'mjd186', 'war861']
# [0, 'UN', 0] ['qdg805', 'vcw157', 'war861']
# [0, 0, 0] ['pgp535', 'eac355', 'war861']
# [1, 3, 0] ['pgp535', 'eac355', 'war861']
# [0, 'UN', 0] ['pgp535', 'eac355', 'war861']
# [0, 0, 0] ['pgp535', 'eac355', 'war861']
# [0, 0, 0] ['pgp535', 'eac355', 'war861']
# [0, 0, 0] ['uiq372', 'eac355', 'war861']
# [3, 0, 0] ['rte579', 'ovk109', 'eac355']
# [2, 0, 2] ['rte579', 'ovk109', 'eac355']
# [0, 0, 0] ['qow112', 'eac355', 'war861']
# [0, 0, 0] ['pgp535', 'eac355', 'war861']
# [1, 0, 0] ['uiq372', 'ygm904', 'eac355']
# [3, 0, 0] ['rte579', 'ovk109', 'eac355']
# [3, 0, 0] ['rte579', 'ovk109', 'eac355']
# [0, 'UN', 0] ['uiq372', 'ygm904', 'war861']
# [1, 0, 0] ['rte579', 'ovk109', 'war861']
# [2, 0, 0] ['rte579', 'ovk109', 'war861']
# [3, 0, 0] ['rte579', 'ovk109', 'war861']
# [3, 0, 0] ['rte579', 'ovk109', 'war861']
# [2, 0, 0] ['rte579', 'ovk109', 'war861']
# [2, 0, 0] ['rte579', 'ovk109', 'war861']
# [2, 0, 0] ['uiq372', 'ovk109', 'bct067']
# [2, 0, 0, 0] ['uiq372', 'ovk109', 'vlh718', 'bct067']
# [2, 0, 0, 4] ['uiq372', 'ovk109', 'vlh718', 'bct067']
# [1, 0, 0, 0] ['uiq372', 'jao767', 'vlh718', 'bct067']
# [1, 0, 0, 0] ['uiq372', 'seu474', 'vlh718', 'bct067']
# [0, 0, 'UN'] ['uiq372', 'byl595', 'vlh718']
# [3, 0, 0] ['uiq372', 'seu474', 'vlh718']
# [0, 2, 'UN'] ['pgp535', 'eac355', 'vlh718']
# [0, 0, 0] ['qow112', 'eac355', 'vlh718']
# [1, 2, 0] ['qow112', 'eac355', 'vlh718']
# [3, 0, 0, 4] ['uiq372', 'seu474', 'vlh718', 'bct067']
# [0, 0, 0] ['qow112', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['qow112', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['uiq372', 'seu474', 'vlh718']
# [0, 0, 'UN'] ['uiq372', 'seu474', 'vlh718']
# [0, 0, 'UN'] ['ovk109', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['ovk109', 'eac355', 'vlh718']
# [0, 0, 'UN', 3] ['uiq372', 'seu474', 'vlh718', 'bct067']
# [0, 0, 0] ['qow112', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['ovk109', 'eac355', 'vlh718']
# [0, 'UN', 'UN'] ['ovk109', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['qow112', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['qow112', 'eac355', 'vlh718']
# ['UN', 0, 'UN'] ['pgp535', 'eac355', 'vlh718']
# [0, 0, 'UN'] ['uiq372', 'seu474', 'vlh718']
# [0, 0, 0, 0] ['ovk109', 'war861', 'vlh718', 'bct067']
# [3, 0, 0, 0] ['uiq372', 'ovk109', 'vlh718', 'bct067']
# ['UN', 0, 0] ['qow112', 'eac355', 'vlh718']
# [0, 0, 'UN', 0] ['ovk109', 'eac355', 'vlh718', 'bct067']
# [1, 0, 0, 0] ['ovk109', 'war861', 'bct067', 'vlh718']
# [0, 0, 'UN', 0] ['ovk109', 'war861', 'vlh718', 'bct067']
# [0, 0, 'UN', 0] ['ovk109', 'war861', 'vlh718', 'bct067']
# [0, 0, 0, 0] ['ovk109', 'war861', 'vlh718', 'bct067']
# [0, 0, 'UN'] ['ovk109', 'war861', 'vlh718']
# [0, 0, 'UN'] ['ovk109', 'war861', 'vlh718']
# ['UN', 0, 'UN', 0] ['qow112', 'war861', 'vlh718', 'bct067']
# [0, 'UN', 'UN', 0] ['ovk109', 'eac355', 'vlh718', 'bct067']
# [3, 0, 4, 0] ['ovk109', 'war861', 'vlh718', 'bct067']
# [0, 0, 0, 0] ['ovk109', 'war861', 'vlh718', 'bct067']

# %%
for rater in agreed:
    score_string = f"{' '.join([f'{agreed[rater][rating]: >4}' for rating in range(0, 5)])}"
    print(rater, score_string)
# Out:
# vbp813   12   24    0   18    0
# aeq969   35    6    3    4    6
# sdu514  133   12   40   36   16
# nuz535   39    4   15   11    3
# npo717    6   15    0    6    3
# ydv934   24   16    4   19    6
# upx953    9    9    0    0    0
# ebf417    0    9    0    0    9
# ifw202   15   18   12    6    0
# yaq494   12   21    9    3    3
# nhf461   33   18   24    6    3
# gry278   27    3   15    3    0
# nrb271   84   18   27    6    0
# nqe273   12   12    9    6    0
# ezi755   36    9    0    3    0
# der817   60   12   12    0    0
# gjx882   34   11   12    8    0
# riq511    6    0    0    0    0
# dpn657   26   43   29   32    4
# guv635    8   32   31   12    8
# qdg805   42   40   35   18    4
# hhq065   15   14    9    7    0
# cru076  318   39   33   15   24
# naz523  189   18    9    9    9
# sxd639    6    0   15   12   12
# ukp255   51    6    0    3    0
# wlv622  108    3    3    0    6
# sdz396   21    3   15   12    6
# xlr671    9    9   27    6    3
# jot226    3    0    3    0    0
# ehp730    3    0    3    0    0
# ntu036    6    0    3    0    3
# pkm714    9    3    9   18   18
# eoh682   33    8   36   26    4
# hht673   25   20   20   30   12
# jge523   41    4   20   14    4
# sjw608   20    0   24    4    0
# ijf406    4    0    0    0    0
# pie341   15    6    9    3   24
# uiq372   55   46   45   39   12
# uid010    4    0    0    0    0
# mjd186    6    6   12    6   18
# kyi500    0    6    0    0    0
# gsq702    6    3    0    0    0
# nas031   24   18    0    6    6
# mjf920    9   12    0    0    6
# awi797    3    3    0    0    0
# vcw157   33    0    0    3    6
# hgx670  213   15    6   21   15
# drc700   51    0    0    6    0
# pgu653    0    6    0    9    0
# ovk109  261   34   35   42   13
# oaw038   12    0    0   12    0
# seu474   31   16    3   11    4
# whs510   12    6    0    3   33
# xeh409    9    9    0    3    3
# dtw334    6    0    0    0    0
# kqt280    9   12   12    0    0
# yik909   36   15    3    3    0
# mlh640    9    9    9    3   21
# xym980    6    0    0    0    0
# xtv059   12   12   24    6    6
# xuq713   36   24    0    0    0
# nve684    9    3    0    0    0
# ajx513   42    0    3    6    3
# pde699   15   18   12    3    6
# trk345   36   15    0    0    3
# lbp656  189   33   18   15   21
# hax813   45    0    0    0    0
# war861  218   13   12   28   22
# pgp535   36    3    6    0    0
# eac355  111    6   12   12    0
# rte579    3    6   21   30    0
# qow112   37    6    0    0    0
# ygm904    3    3    0    0    0
# bct067  115   16   11   16   20
# vlh718  122   19   11   11   16
# jao767    8    4    0    0    0
# byl595    3    0    0    0    0

# %% [markdown]
# #### Observations
#
# Some annotators who seem to mostly disagree strongly with others are:
# - sxd639
# - pkm714
# - mjd186
# - whs510
# - mlh640
#
# This could be a signal that they misinterpreted the impact categories, or the rating scale.
#
# It could also signal that they purposefully gave random or wrong answers.

# %% [markdown]
# ## Misunderstanding Annotators
#
# Some annotators may have thought that the default rating is the middle one ($rating=2$ in this case), such that even a rating of 1 is a signal that an impact category is not clearly present. That is, perhaps they thought that 0 is absolute certainty that some category is present, while 1 leaves some doubt,, so they are inclined to always rate all categories higher than 0.

# %%
import copy

non_zeros = Counter()

for sent in data:
    if sent['excluded'] is True:
        continue
    sent = copy.deepcopy(sent)
    for anno in sent['annotations']:
        ratings = [get_scale_rating(anno, field) for field in anno if '_scale' in field]
        digit_ratings = [rating for rating in ratings if isinstance(rating, int)]
        non_zero_ratings = [rating for rating in digit_ratings if rating > 0]
        #print(len(scores))
        if len(non_zero_ratings) == 8:
            print(anno['annotator'], non_zero_ratings)
            non_zeros.update([anno['annotator']])

for rater, freq in non_zeros.most_common():
    print(rater, freq)
# Out:
# ifw202 [2, 2, 3, 1, 4, 1, 3, 1]
# ifw202 [2, 3, 3, 3, 2, 1, 3, 1]
# ifw202 [2, 2, 3, 3, 2, 2, 2, 2]
# ifw202 [2, 3, 3, 2, 3, 1, 2, 3]
# ifw202 [2, 3, 2, 3, 2, 2, 2, 3]
# ifw202 [3, 2, 3, 2, 2, 2, 2, 2]
# yaq494 [2, 4, 4, 4, 4, 4, 4, 2]
# gry278 [3, 2, 2, 3, 3, 1, 2, 2]
# gry278 [1, 1, 2, 2, 1, 1, 1, 3]
# dpn657 [2, 1, 2, 2, 1, 1, 3, 1]
# dpn657 [4, 2, 3, 2, 2, 2, 2, 2]
# dpn657 [2, 3, 4, 3, 2, 1, 2, 1]
# pkm714 [1, 3, 3, 1, 1, 1, 2, 2]
# pkm714 [3, 4, 3, 1, 3, 1, 2, 2]
# pkm714 [2, 2, 3, 1, 4, 1, 2, 4]
# eoh682 [3, 2, 3, 1, 3, 1, 2, 2]
# jge523 [2, 2, 3, 2, 2, 2, 2, 2]
# eoh682 [3, 1, 3, 1, 1, 1, 3, 1]
# dpn657 [2, 2, 2, 1, 2, 1, 2, 2]
# mjd186 [2, 3, 3, 1, 2, 2, 3, 3]
# whs510 [1, 3, 4, 1, 1, 1, 1, 3]
# mlh640 [4, 3, 1, 2, 2, 2, 2, 2]
# pde699 [2, 2, 2, 2, 2, 2, 2, 2]
# pde699 [3, 3, 4, 3, 3, 3, 3, 4]
# pde699 [2, 2, 3, 2, 2, 1, 1, 2]
# pde699 [1, 1, 1, 1, 2, 2, 1, 1]
# whs510 [3, 4, 4, 1, 3, 1, 1, 1]
# pgu653 [1, 1, 3, 1, 4, 1, 1, 3]
# dpn657 [4, 2, 3, 1, 3, 1, 1, 3]
# rte579 [3, 4, 1, 3, 3, 1, 1, 2]
# rte579 [3, 3, 2, 2, 2, 2, 2, 1]
# rte579 [3, 4, 3, 4, 4, 1, 2, 2]
# rte579 [2, 2, 2, 2, 2, 2, 2, 2]
# rte579 [2, 2, 2, 2, 2, 2, 2, 2]
# ifw202 6
# dpn657 5
# rte579 5
# pde699 4
# pkm714 3
# gry278 2
# eoh682 2
# whs510 2
# yaq494 1
# jge523 1
# mjd186 1
# mlh640 1
# pgu653 1

# %%
def get_annotator_anno(sent, annotator):
    for anno in sent['annotations']:
        if anno['annotator'] == annotator:
            return anno
    
def has_annotator(sent, annotator):
    return annotator in [anno['annotator'] for anno in sent['annotations']]

def filter_sents_by_annotator(sents, annotator):
    return [sent for sent in sents if has_annotator(sent, annotator)]

annotator = 'ifw202'
sents = filter_sents_by_annotator(data, annotator)
len(sents)
for sent in sorted(sents, key = lambda sent: get_annotator_anno(sent, annotator)['created']):
    anno = get_annotator_anno(sent, annotator)
    scores = [anno[field] for field in anno if '_scale' in field and int(anno[field])]
    print(sent['text'])
    print(anno['created'], anno['modified'] if 'modified' in anno else None)
    print(scores)
# Out:
# To say this read takes you on a voyage is not giving it enough credit.
# 2020-10-12T19:28:38.583004+00:00 None
# ['2', '2', '3', '1', '4', '1', '3', '1']
# I struggled a little with the connection between them... and I don't really understand how some of the secondary characters actually fit.
#
# 2020-10-12T19:30:04.539341+00:00 None
# ['2', '2', '2', '3', '3', '1', '3']
# And then you'll give me the '2 months later' crap next chapter wherein he's instantly recovered from a brain tumor.
# 2020-10-12T19:31:03.258800+00:00 None
# ['2', '3', '3']
# The techniques are all clearly laid out and there are a good variety of projects to choose from.
# 2020-10-12T19:32:47.698929+00:00 None
# ['2', '2', '3', '3', '2', '2', '2', '2']
# And then there was Jacob O'Connor.
# 2020-10-12T19:33:34.769477+00:00 None
# ['3', '2', '3', '2', '2', '2', '2', '2']
# Well it takes others a little longer.
# 2020-10-12T19:35:10.229683+00:00 None
# ['2', '3', '2', '3', '2', '2', '2', '3']
# This was a wonderful thid book for this series and I'm so happy I got to read their story.
# 2020-10-12T19:36:04.586079+00:00 None
# ['2', '2', '4', '2', '3', '1', '3']
# I liked this sequel but not quite as much as the first one (A Dog's Purpose).
# 2020-10-12T19:37:11.653292+00:00 None
# ['2', '3', '3', '2', '3', '1', '2', '3']
# Lots of twists and turns and good characters.
# 2020-10-12T19:37:57.090092+00:00 None
# ['3', '3', '4', '3', '3', '2', '4']
# The dual narrative provides a deep connection and level of understanding to both characters, Aly and Brandon.
# 2020-10-12T19:39:39.052778+00:00 None
# ['2', '3', '3', '3', '2', '1', '3', '1']

# %% [markdown]
# For annotator `ifw202` the switch between moving all buttons and moving only a few seems unrelated to the order in which they annotated the sentences. It does not look like an initial misunderstanding that got cleared up after a few sentences.

# %% [markdown]
# ## Lemmatizing sentences

# %%
import spacy
from spacy import displacy


spacy.__version__
# Out:
# '3.0.6'

# %%
nlp = spacy.load("en_core_web_trf")

# %%
for sent in data[225:]:
    doc = nlp(sent['text'])
    break
    
for chunk in doc.noun_chunks:
    print(chunk)
    
    
displacy.render(doc, style='dep')
# Out:
# Only three children
# Taylor
# this trio
# a Cadet
# a Townie
# an epic friendship
# the foundation
# the many mysteries
# her life
# identity
# the war games
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ff6782f35c284409bd12d6a2fb6c0393-0" class="displacy" width="7050" height="837.0" direction="ltr" style="max-width: none; height: 837.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">three</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">children</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">survived,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Taylor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">discovers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">trio,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">plus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">Cadet</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">Townie,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">developed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3025">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">epic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3375">friendship</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3550">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3725">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="3900">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4075">foundation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4425">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4600">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4775">mysteries</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="4950">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5125">her</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="747.0">
#     <tspan class="displacy-word" fill="currentColor" x="5300">life</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentCo

# %%
for ent in doc.ents:
    print(ent.text, ent.start, ent.label_)
    
for token in doc:
    print(token.text, token.pos_, token.lemma_)
# Out:
# Only three 0 CARDINAL
# Taylor 6 PERSON
# Cadet 14 PRODUCT
# Townie 17 PRODUCT
# Only ADV only
# three NUM three
# children NOUN child
# survived VERB survive
# , PUNCT ,
# and CCONJ and
# Taylor PROPN Taylor
# discovers VERB discover
# that SCONJ that
# this DET this
# trio NOUN trio
# , PUNCT ,
# plus CCONJ plus
# a DET a
# Cadet PROPN Cadet
# and CCONJ and
# a DET a
# Townie PROPN Townie
# , PUNCT ,
# developed VERB develop
# an DET an
# epic ADJ epic
# friendship NOUN friendship
# that DET that
# was VERB be
# the DET the
# foundation NOUN foundation
# of ADP of
# the DET the
# many ADJ many
# mysteries NOUN mystery
# in ADP in
# her PRON her
# life NOUN life
# and CCONJ and
# identity NOUN identity
# , PUNCT ,
# as ADV as
# well ADV well
# as ADP as
# of ADP of
# the DET the
# war NOUN war
# games NOUN game
# . PUNCT .
